# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import tensorflow_decision_forests as tfdf
import tensorflow as tf
from tqdm import tqdm
from catboost import CatBoostRegressor

# %matplotlib inline

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
# Out:
# 2023-11-08 15:16:57.304625: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
starting_directory = '.'

# %%
train_a = pd.read_parquet(f'{starting_directory}/A/train_targets.parquet')
train_b = pd.read_parquet(f'{starting_directory}/B/train_targets.parquet')
train_c = pd.read_parquet(f'{starting_directory}/C/train_targets.parquet')

# %%
X_train_estimated_a = pd.read_parquet(f'{starting_directory}/A/X_train_estimated.parquet')
X_train_estimated_b = pd.read_parquet(f'{starting_directory}/B/X_train_estimated.parquet')
X_train_estimated_c = pd.read_parquet(f'{starting_directory}/C/X_train_estimated.parquet')

X_train_observed_a = pd.read_parquet(f'{starting_directory}/A/X_train_observed.parquet')
X_train_observed_b = pd.read_parquet(f'{starting_directory}/B/X_train_observed.parquet')
X_train_observed_c = pd.read_parquet(f'{starting_directory}/C/X_train_observed.parquet')

X_test_estimated_a = pd.read_parquet(f'{starting_directory}/A/X_test_estimated.parquet')
X_test_estimated_b = pd.read_parquet(f'{starting_directory}/B/X_test_estimated.parquet')
X_test_estimated_c = pd.read_parquet(f'{starting_directory}/C/X_test_estimated.parquet')

# %%
def removeConstants(data):
    constant_columns = []
    set_num=0
    new_data = []

    for df in data:
        for column in df.columns:
            # Add constant
            if df[column].nunique() == 1 and set_num == 0:
                constant_columns.append(column)
            elif df[column].nunique() != 1 and column in constant_columns:
                # Pop impostor
                constant_columns.remove(column)
        set_num += 1
    
    for df in data:
        new_df = df.drop(columns=constant_columns)
        new_data.append(new_df)
    
    print("Column(s)", constant_columns, "was removed")
    return new_data

# %%
def fillNaN(data):
    new_data = []
    for df in data:
        for column in df.columns:
            df[column] = df[column].interpolate()
        new_data.append(df)
    return new_data

def quartersToHours(data):
    hourly_data = []
    for df in data:    
        df["year"] = df['date_forecast'].dt.year
        df["month"] = df['date_forecast'].dt.month
        df["day"] = df['date_forecast'].dt.day
        df["hour"] = df['date_forecast'].dt.hour
    
        group = df.groupby([df["year"], df["month"], df["day"], df["hour"]])  
        result = group.mean()
        result = result.reset_index()
    
        return_df = result.drop(['year', 'month', 'day', 'hour'], axis=1)
        
        hourly_data.append(return_df)

    return hourly_data

def convert_date_to_sin_and_cos(data):
    new_data = []
    for df in data:
        hour = 60*60
        day = 24*60*60
        year = (365.2425)*day
        month = year / 12.0
        
        df["year"] = [df["date_forecast"][i].year for i in range(len(df))]
        df["hour"] = [df["date_forecast"][i].hour for i in range(len(df))]
    
        date_time = pd.to_datetime(df.pop('date_forecast'), format='%Y-%m.%d %H:%M:%S')
        timestamp_s = date_time.map(pd.Timestamp.timestamp)
    
        df['hour_sin'] = np.sin(timestamp_s * (2 * np.pi / day))
        df['hour_cos'] = np.cos(timestamp_s * (2 * np.pi / day))
        df['year_sin'] = np.sin(timestamp_s * (2 * np.pi / year))
        df['year_cos'] = np.cos(timestamp_s * (2 * np.pi / year))
        new_data.append(df)
    return new_data


def appendLabels(train, val, labels):
    # Rename columns names to match
    val = val.assign(date_forecast=val.date_forecast.dt.round('H'))
    train = train.assign(date_forecast=train.date_forecast.dt.round('H'))

    labels = labels.rename(columns={'time': 'date_forecast'})
    
    joined_train = pd.merge(train, labels, how="inner", on="date_forecast")
    joined_val = pd.merge(val, labels, how="inner", on="date_forecast")

    return [joined_train, joined_val]

# Remove date columns
def removeNonNumeric(data):
    numeric_data = []
    for df in data:
        non_numeric_columns = df.select_dtypes(exclude='number').columns.tolist()
        df.drop(columns=non_numeric_columns, inplace=True)
        numeric_data.append(df)
    return numeric_data

def removeNaN(data):
    new_data = []
    for df in data:
        if 'pv_measurement' in df.columns:
            df = df.dropna(subset=['pv_measurement'])
        new_data.append(df)
    return new_data

# %%
A = [X_train_observed_a, X_train_estimated_a, X_test_estimated_a]
B = [X_train_observed_b, X_train_estimated_b, X_test_estimated_b]
C = [X_train_observed_c, X_train_estimated_c, X_test_estimated_c]

A = removeConstants(A)
A = removeConstants(B)
A = removeConstants(C)

A = quartersToHours(A)
B = quartersToHours(B)
C = quartersToHours(C)

A[:2] = appendLabels(A[0], A[1], train_a)
B[:2] = appendLabels(B[0], B[1], train_b)
C[:2] = appendLabels(C[0], C[1], train_c)

#A = convert_date_to_sin_and_cos(A)
#B = convert_date_to_sin_and_cos(B)
#C = convert_date_to_sin_and_cos(C)

A = fillNaN(A)
B = fillNaN(B)
C = fillNaN(C)

A = removeNonNumeric(A)
B = removeNonNumeric(B)
C = removeNonNumeric(C)

A = removeNaN(A)
B = removeNaN(B)
C = removeNaN(C)
# Out:
# Column(s) ['elevation:m', 'snow_drift:idx'] was removed
# Column(s) ['elevation:m'] was removed
# Column(s) ['elevation:m'] was removed

# %%
# Function to find and remove sequences with 12 or more identical subsequent values
def removeSequences(data):
    new_data = []
    for df in tqdm(data):
        start_idx = None
        prev_value = None
        subsequent_count = 0
        for idx, value in enumerate(df['pv_measurement']):
            if subsequent_count >= 1000:
                df = df.drop(df.index[idx-24:idx])
                subsequent_count == 0                
            
            if prev_value != None:
                if value - prev_value < 0.1:
                    subsequent_count += 1
            
                else:
                    prev_value = value
                    subsequent_count = 0
            else:
                prev_value = value
             
        new_data.append(df)

    return new_data


#A = removeSequences(A)
#B = removeSequences(B)
#C = removeSequences(C)

# %%
#C[0] = C[0][5800:]
#B[0].drop(index=B[0].iloc[13310:14560].index.tolist(), axis=0, inplace=True)
# Assuming df is your DataFrame
# Remove rows 13310 to 14560

C[0] = C[0].drop(C[0].index[:5800])

B[0] = B[0].drop(B[0].index[13310:14561])
#B[0] = B[0].drop(B[0].index[15000:18000])

# Reset the index
B[0] = B[0].reset_index(drop=True)
C[0] = C[0].reset_index(drop=True)

plt.plot(A[0]['pv_measurement'])
plt.show()
plt.plot(B[0]['pv_measurement'])
plt.show()
plt.plot(C[0]['pv_measurement'])

# %%
#dataset = numpy.array([[1,4,5,6],[4,5,6,7],[30,40,50,60],[20,15,85,60]])
#train_labels = [1.2,3.4,9.5,24.5]
model = CatBoostRegressor(learning_rate=1, depth=6, loss_function='RMSE')

model_a = model.fit(A[0], A[0]['pv_measurement'])
model_b = model.fit(B[0], B[0]['pv_measurement'])
model_c = model.fit(C[0], C[0]['pv_measurement'])

#print(model_a.get_params())
# Out:
# 0:	learn: 257.1907244	total: 32.1ms	remaining: 32.1s
# 1:	learn: 171.4653003	total: 75.4ms	remaining: 37.6s
# 2:	learn: 124.6218464	total: 84.5ms	remaining: 28.1s
# 3:	learn: 109.6209873	total: 94.6ms	remaining: 23.6s
# 4:	learn: 85.1131529	total: 104ms	remaining: 20.7s
# 5:	learn: 76.0461568	total: 113ms	remaining: 18.7s
# 6:	learn: 68.3656664	total: 121ms	remaining: 17.1s
# 7:	learn: 63.5610977	total: 128ms	remaining: 15.9s
# 8:	learn: 55.3947186	total: 138ms	remaining: 15.2s
# 9:	learn: 46.7333772	total: 148ms	remaining: 14.6s
# 10:	learn: 44.0319627	total: 161ms	remaining: 14.4s
# 11:	learn: 38.4811407	total: 174ms	remaining: 14.3s
# 12:	learn: 36.2500434	total: 186ms	remaining: 14.1s
# 13:	learn: 33.2320718	total: 194ms	remaining: 13.7s
# 14:	learn: 32.3312214	total: 205ms	remaining: 13.4s
# 15:	learn: 31.3701155	total: 213ms	remaining: 13.1s
# 16:	learn: 29.8597495	total: 221ms	remaining: 12.8s
# 17:	learn: 27.3980118	total: 229ms	remaining: 12.5s
# 18:	learn: 26.2445226	total: 260ms	remaining: 13.4s
# 19:	learn: 25.3306625	total: 268ms	remaining: 13.1s
# 20:	learn: 24.3759229	total: 278ms	remaining: 13s
# 21:	learn: 23.8998765	total: 286ms	remaining: 12.7s
# 22:	learn: 22.9372520	total: 297ms	remaining: 12.6s
# 23:	learn: 22.2374692	total: 305ms	remaining: 12.4s
# 24:	learn: 20.8320286	total: 315ms	remaining: 12.3s
# 25:	learn: 19.7553094	total: 326ms	remaining: 12.2s
# 26:	learn: 19.4620323	total: 335ms	remaining: 12.1s
# 27:	learn: 18.6732055	total: 343ms	remaining: 11.9s
# 28:	learn: 18.3109361	total: 353ms	remaining: 11.8s
# 29:	learn: 17.7057987	total: 361ms	remaining: 11.7s
# 30:	learn: 17.3326082	total: 370ms	remaining: 11.6s
# 31:	learn: 16.9575741	total: 380ms	remaining: 11.5s
# 32:	learn: 16.3943543	total: 389ms	remaining: 11.4s
# 33:	learn: 15.7389607	total: 400ms	remaining: 11.4s
# 34:	learn: 15.5197186	total: 410ms	remaining: 11.3s
# 35:	learn: 15.1358207	total: 418ms	remaining: 11.2s
# 36:	learn: 14.9089434	total: 426ms	remaining: 11.1s
# 37:	learn: 14.6065138	total: 434ms	remaining: 11s
# 38:	learn: 14.2937153	total: 442ms	remaining: 10.9s
# 39:	learn: 14.1220708	total: 450ms	remaining: 10.8s
# 40:	learn: 13.9568317	total: 460ms	remaining: 10.8s
# 41:	learn: 13.7679875	total: 481ms	remaining: 11s
# 42:	learn: 13.4148167	total: 497ms	remaining: 11.1s
# 43:	learn: 13.1194889	total: 505ms	remaining: 11s
# 44:	learn: 12.9203562	total: 514ms	remaining: 10.9s
# 45:	learn: 12.8582449	total: 523ms	remaining: 10.8s
# 46:	learn: 12.7355734	total: 531ms	remaining: 10.8s
# 47:	learn: 12.5129415	total: 541ms	remaining: 10.7s
# 48:	learn: 12.2089641	total: 551ms	remaining: 10.7s
# 49:	learn: 11.8793063	total: 566ms	remaining: 10.8s
# 50:	learn: 11.8063478	total: 577ms	remaining: 10.7s
# 51:	learn: 11.6555104	total: 588ms	remaining: 10.7s
# 52:	learn: 11.5005391	total: 597ms	remaining: 10.7s
# 53:	learn: 11.3202921	total: 607ms	remaining: 10.6s
# 54:	learn: 11.1764144	total: 618ms	remaining: 10.6s
# 55:	learn: 11.1084371	total: 630ms	remaining: 10.6s
# 56:	learn: 11.0239133	total: 639ms	remaining: 10.6s
# 57:	learn: 10.8642923	total: 650ms	remaining: 10.5s
# 58:	learn: 10.6765013	total: 661ms	remaining: 10.5s
# 59:	learn: 10.5843545	total: 709ms	remaining: 11.1s
# 60:	learn: 10.4368206	total: 723ms	remaining: 11.1s
# 61:	learn: 10.4093359	total: 733ms	remaining: 11.1s
# 62:	learn: 10.3483047	total: 743ms	remaining: 11s
# 63:	learn: 10.2195866	total: 752ms	remaining: 11s
# 64:	learn: 10.1506316	total: 759ms	remaining: 10.9s
# 65:	learn: 10.0560241	total: 770ms	remaining: 10.9s
# 66:	learn: 9.9678287	total: 781ms	remaining: 10.9s
# 67:	learn: 9.9185445	total: 790ms	remaining: 10.8s
# 68:	learn: 9.8452225	total: 800ms	remaining: 10.8s
# 69:	learn: 9.7020907	total: 810ms	remaining: 10.8s
# 70:	learn: 9.6198671	total: 820ms	remaining: 10.7s
# 71:	learn: 9.5860675	total: 828ms	remaining: 10.7s
# 72:	learn: 9.3879302	total: 839ms	remaining: 10.7s
# 73:	learn: 9.2887632	total: 847ms	remaining: 10.6s
# 74:	learn: 9.1968863	total: 858ms	remaining: 10.6s
# 75:	learn: 9.0829342	total: 873ms	remaining: 10.6s
# 76:	learn: 9.0171925	total: 891ms	remaining: 10.7s
# 77:	learn: 8.7908746	total: 913ms	remaining: 10.8s
# 78:	learn: 8.5214039	total: 924ms	remaining: 10.8s
# 79:	learn: 8.4458975	total: 937ms	remaining: 10.8s
# 80:	learn: 8.4039616	total: 949ms	remaining: 10.8s
# 81:	learn: 8.3340195	total: 957ms	remaining: 10.7s
# 82:	learn: 8.3013402	total: 965ms	remaining: 10.7s
# 83:	learn: 8.2511587	total: 974ms	remaining: 10.6s
# 84:	learn: 8.1842521	total: 983ms	remaining: 10.6s
# 85:	learn: 8.1037574	total: 991ms	remaining: 10.5s
# 86:	learn: 8.0386013	total: 1s	remaining: 10.5s
# 87:	learn: 7.9467051	total: 1.02s	remaining: 10.6s
# 88:	learn: 7.8948077	total: 1.11s	remaining: 11.3s
# 89:	learn: 7.8395637	total: 1.12s	remaining: 11.4s
# 90:	learn: 7.7815005	total: 1.13s	remaining: 11.3s
# 91:	learn: 7.7582010	total: 1.14s	remaining: 11.3s
# 92:	learn: 7.7089376	total: 1.15s	remaining: 11.2s
# 93:	learn: 7.6500907	total: 1.16s	remaining: 11.2s
# 94:	learn: 7.5422469	total: 1.17s	remaining: 11.1s
# 95:	learn: 7.5122483	total: 1.18s	remaining: 11.1s
# 96:	learn: 7.4480756	total: 1.19s	remaining: 11.1s
# 97:	learn: 7.4179711	total: 1.2s	remaining: 11s
# 98:	learn: 7.3799218	total: 1.2s	remaining: 11s
# 99:	learn: 7.3428304	total: 1.21s	remaining: 10.9s
# 100:	learn: 7.3140351	total: 1.22s	remaining: 10.9s
# 101:	learn: 7.2038548	total: 1.23s	remaining: 10.8s
# 102:	learn: 7.1403661	total: 1.24s	remaining: 10.8s
# 103:	learn: 7.1118492	total: 1.25s	remaining: 10.7s
# 104:	learn: 7.0591949	total: 1.25s	remaining: 10.7s
# 105:	learn: 7.0195396	total: 1.26s	remaining: 10.7s
# 106:	learn: 6.9852843	total: 1.27s	remaining: 10.6s
# 107:	learn: 6.9416246	total: 1.28s	remaining: 10.6s
# 108:	learn: 6.9022057	total: 1.29s	remaining: 10.5s
# 109:	learn: 6.8521710	total: 1.3s	remaining: 10.5s
# 110:	learn: 6.8138964	total: 1.31s	remaining: 10.5s
# 111:	learn: 6.7856033	total: 1.35s	remaining: 10.7s
# 112:	learn: 6.7640279	total: 1.36s	remaining: 10.7s
# 113:	learn: 6.7405856	total: 1.37s	remaining: 10.7s
# 114:	learn: 6.6788620	total: 1.38s	remaining: 10.7s
# 115:	learn: 6.6110022	total: 1.39s	remaining: 10.6s
# 116:	learn: 6.5786537	total: 1.4s	remaining: 10.6s
# 117:	learn: 6.5479611	total: 1.42s	remaining: 10.6s
# 118:	learn: 6.5260729	total: 1.42s	remaining: 10.5s
# 119:	learn: 6.4982857	total: 1.43s	remaining: 10.5s
# 120:	learn: 6.4718142	total: 1.44s	remaining: 10.5s
# 121:	learn: 6.4396978	total: 1.45s	remaining: 10.4s
# 122:	learn: 6.3999827	total: 1.46s	remaining: 10.4s
# 123:	learn: 6.3705658	total: 1.47s	remaining: 10.4s
# 124:	learn: 6.3408798	total: 1.48s	remaining: 10.3s
# 125:	learn: 6.3151221	total: 1.48s	remaining: 10.3s
# 126:	learn: 6.3007817	total: 1.49s	remaining: 10.3s
# 127:	learn: 6.2705835	total: 1.5s	remaining: 10.2s
# 128:	learn: 6.2398791	total: 1.52s	remaining: 10.3s
# 129:	learn: 6.1834555	total: 1.54s	remaining: 10.3s
# 130:	learn: 6.1397975	total: 1.56s	remaining: 10.3s
# 131:	learn: 6.1209607	total: 1.57s	remaining: 10.3s
# 132:	learn: 6.0703500	total: 1.58s	remaining: 10.3s
# 133:	learn: 6.0387876	total: 1.6s	remaining: 10.4s
# 134:	learn: 6.0172987	total: 1.62s	remaining: 10.4s
# 135:	learn: 5.9786714	total: 1.63s	remaining: 10.4s
# 136:	learn: 5.9599122	total: 1.65s	remaining: 10.4s
# 137:	learn: 5.9373455	total: 1.66s	remaining: 10.4s
# 138:	learn: 5.9012780	total: 1.68s	remaining: 10.4s
# 139:	learn: 5.8787276	total: 1.68s	remaining: 10.3s
# 140:	learn: 5.8593264	total: 1.69s	remaining: 10.3s
# 141:	learn: 5.8254813	total: 1.7s	remaining: 10.3s
# 142:	learn: 5.8056714	total: 1.72s	remaining: 10.3s
# 143:	learn: 5.7734811	total: 1.74s	remaining: 10.3s
# 144:	learn: 5.7323275	total: 1.75s	remaining: 10.3s
# 145:	learn: 5.7111608	total: 1.76s	remaining: 10.3s
# 146:	learn: 5.6868251	total: 1.78s	remaining: 10.3s
# 147:	learn: 5.6527407	total: 1.79s	remaining: 10.3s
# 148:	learn: 5.6239710	total: 1.79s	remaining: 10.3s
# 149:	learn: 5.6029177	total: 1.81s	remaining: 10.2s
# 150:	learn: 5.5811977	total: 1.82s	remaining: 10.2s
# 151:	learn: 5.5564719	total: 1.82s	remaining: 10.2s
# 152:	learn: 5.5376537	total: 1.83s	remaining: 10.1s
# 153:	learn: 5.5174241	total: 1.84s	remaining: 10.1s
# 154:	learn: 5.5002184	total: 1.85s	remaining: 10.1s
# 155:	learn: 5.4754694	total: 1.86s	remaining: 10.1s
# 156:	learn: 5.4463828	total: 1.87s	remaining: 10s
# 157:	learn: 5.4227920	total: 1.88s	remaining: 10s
# 158:	learn: 5.4042884	total: 1.88s	remaining: 9.97s
# 159:	learn: 5.3854377	total: 1.89s	remaining: 9.94s
# 160:	learn: 5.3620808	total: 1.9s	remaining: 9.91s
# 161:	learn: 5.3395675	total: 1.92s	remaining: 9.92s
# 162:	learn: 5.3208417	total: 1.93s	remaining: 9.89s
# 163:	learn: 5.2980632	total: 1.94s	remaining: 9.87s
# 164:	learn: 5.2609427	total: 1.95s	remaining: 9.85s
# 165:	learn: 5.2319170	total: 1.96s	remaining: 9.83s
# 166:	learn: 5.2071578	total: 1.96s	remaining: 9.8s
# 167:	learn: 5.1897753	total: 1.97s	remaining: 9.77s
# 168:	learn: 5.1607973	total: 1.98s	remaining: 9.75s
# 169:	learn: 5.1291810	total: 1.99s	remaining: 9.72s
# 170:	learn: 5.1158956	total: 2s	remaining: 9.7s
# 171:	learn: 5.0981818	total: 2.01s	remaining: 9.67s
# 172:	learn: 5.0739800	total: 2.02s	remaining: 9.64s
# 173:	learn: 5.0582382	total: 2.03s	remaining: 9.62s
# 174:	learn: 5.0292531	total: 2.04s	remaining: 9.63s
# 175:	learn: 5.0160093	total: 2.06s	remaining: 9.63s
# 176:	learn: 5.0047715	total: 2.07s	remaining: 9.64s
# 177:	learn: 4.9848115	total: 2.08s	remaining: 9.63s
# 178:	learn: 4.9767371	total: 2.09s	remaining: 9.61s
# 179:	learn: 4.9608846	total: 2.1s	remaining: 9.58s
# 180:	learn: 4.9386370	total: 2.11s	remaining: 9.57s
# 181:	learn: 4.9221742	total: 2.13s	remaining: 9.59s
# 182:	learn: 4.8938738	total: 2.15s	remaining: 9.58s
# 183:	learn: 4.8809769	total: 2.15s	remaining: 9.55s
# 184:	learn: 4.8640805	total: 2.16s	remaining: 9.53s
# 185:	learn: 4.8483383	total: 2.17s	remaining: 9.5s
# 186:	learn: 4.8429681	total: 2.18s	remaining: 9.48s
# 187:	learn: 4.8292291	total: 2.19s	remaining: 9.47s
# 188:	learn: 4.8158674	total: 2.21s	remaining: 9.49s
# 189:	learn: 4.7830979	total: 2.23s	remaining: 9.49s
# 190:	learn: 4.7544604	total: 2.24s	remaining: 9.48s
# 191:	learn: 4.7372064	total: 2.25s	remaining: 9.46s
# 192:	learn: 4.7194811	total: 2.26s	remaining: 9.44s
# 193:	learn: 4.6960675	total: 2.27s	remaining: 9.42s
# 194:	learn: 4.6793861	total: 2.28s	remaining: 9.4s
# 195:	learn: 4.6637131	total: 2.28s	remaining: 9.37s
# 196:	learn: 4.6507753	total: 2.29s	remaining: 9.34s
# 197:	learn: 4.6352627	total: 2.3s	remaining: 9.32s
# 198:	learn: 4.6182070	total: 2.31s	remaining: 9.29s
# 199:	learn: 4.6026248	total: 2.32s	remaining: 9.27s
# 200:	learn: 4.5883491	total: 2.33s	remaining: 9.25s
# 201:	learn: 4.5760099	total: 2.34s	remaining: 9.25s
# 202:	learn: 4.5594947	total: 2.37s	remaining: 9.29s
# 203:	learn: 4.5328679	total: 2.39s	remaining: 9.31s
# 204:	learn: 4.5198218	total: 2.4s	remaining: 9.3s
# 205:	learn: 4.4991660	total: 2.41s	remaining: 9.29s
# 206:	learn: 4.4835141	total: 2.42s	remaining: 9.28s
# 207:	learn: 4.4712172	total: 2.44s	remaining: 9.28s
# 208:	learn: 4.4563621	total: 2.45s	remaining: 9.26s
# 209:	learn: 4.4327445	total: 2.46s	remaining: 9.25s
# 210:	learn: 4.4183132	total: 2.47s	remaining: 9.22s
# 211:	learn: 4.4035816	total: 2.48s	remaining: 9.21s
# 212:	learn: 4.3894578	total: 2.49s	remaining: 9.19s
# 213:	learn: 4.3698654	total: 2.5s	remaining: 9.18s
# 214:	learn: 4.3579475	total: 2.51s	remaining: 9.17s
# 215:	learn: 4.3378608	total: 2.52s	remaining: 9.15s
# 216:	learn: 4.3051952	total: 2.53s	remaining: 9.14s
# 217:	learn: 4.2946205	total: 2.56s	remaining: 9.17s
# 218:	learn: 4.2803324	total: 2.58s	remaining: 9.19s
# 219:	learn: 4.2642039	total: 2.6s	remaining: 9.23s
# 220:	learn: 4.2486331	total: 2.62s	remaining: 9.22s
# 221:	learn: 4.2383586	total: 2.63s	remaining: 9.21s
# 222:	learn: 4.2244627	total: 2.64s	remaining: 9.21s
# 223:	learn: 4.2049648	total: 2.65s	remaining: 9.2s
# 224:	learn: 4.1852853	total: 2.67s	remaining: 9.18s
# 225:	learn: 4.1614749	total: 2.67s	remaining: 9.16s
# 226:	learn: 4.1510574	total: 2.68s	remaining: 9.14s
# 227:	learn: 4.1350094	total: 2.69s	remaining: 9.11s
# 228:	learn: 4.1204374	total: 2.7s	remaining: 9.09s
# 229:	learn: 4.1000156	total: 2.71s	remaining: 9.07s
# 230:	learn: 4.0921970	total: 2.72s	remaining: 9.04s
# 231:	learn: 4.0766517	total: 2.73s	remaining: 9.02s
# 232:	learn: 4.0652079	total: 2.73s	remaining: 9s
# 233:	learn: 4.0449197	total: 2.74s	remaining: 8.98s
# 234:	learn: 4.0274536	total: 2.75s	remaining: 8.96s
# 235:	learn: 4.0165182	total: 2.77s	remaining: 8.97s
# 236:	learn: 4.0017171	total: 2.79s	remaining: 8.98s
# 237:	learn: 3.9924334	total: 2.81s	remaining: 8.99s
# 238:	learn: 3.9824338	total: 2.82s	remaining: 8.98s
# 239:	learn: 3.9723199	total: 2.84s	remaining: 8.99s
# 240:	learn: 3.9629393	total: 2.85s	remaining: 8.98s
# 241:	learn: 3.9499737	total: 2.86s	remaining: 8.97s
# 242:	learn: 3.9398563	total: 2.87s	remaining: 8.95s
# 243:	learn: 3.9289860	total: 2.89s	remaining: 8.95s
# 244:	learn: 3.9204833	total: 2.9s	remaining: 8.95s
# 245:	learn: 3.9009598	total: 2.91s	remaining: 8.93s
# 246:	learn: 3.8885924	total: 2.92s	remaining: 8.92s
# 247:	learn: 3.8709171	total: 2.94s	remaining: 8.91s
# 248:	learn: 3.8562287	total: 2.95s	remaining: 8.89s
# 249:	learn: 3.8441625	total: 2.96s	remaining: 8.88s
# 250:	learn: 3.8279971	total: 2.97s	remaining: 8.87s
# 251:	learn: 3.8197701	total: 3s	remaining: 8.9s
# 252:	learn: 3.8100661	total: 3.01s	remaining: 8.89s
# 253:	learn: 3.7958793	total: 3.02s	remaining: 8.88s
# 254:	learn: 3.7802982	total: 3.04s	remaining: 8.87s
# 255:	learn: 3.7692487	total: 3.05s	remaining: 8.87s
# 256:	learn: 3.7572629	total: 3.06s	remaining: 8.85s
# 257:	learn: 3.7446474	total: 3.07s	remaining: 8.84s
# 258:	learn: 3.7293230	total: 3.08s	remaining: 8.82s
# 259:	learn: 3.7171625	total: 3.1s	remaining: 8.83s
# 260:	learn: 3.7060421	total: 3.12s	remaining: 8.84s
# 261:	learn: 3.6881952	total: 3.14s	remaining: 8.85s
# 262:	learn: 3.6697801	total: 3.15s	remaining: 8.84s
# 263:	learn: 3.6613338	total: 3.17s	remaining: 8.83s
# 264:	learn: 3.6461803	total: 3.18s	remaining: 8.81s
# 265:	learn: 3.6331671	total: 3.19s	remaining: 8.81s
# 266:	learn: 3.6282257	total: 3.21s	remaining: 8.82s
# 267:	learn: 3.6159556	total: 3.22s	remaining: 8.8s
# 268:	learn: 3.6026301	total: 3.24s	remaining: 8.8s
# 269:	learn: 3.5878384	total: 3.25s	remaining: 8.8s
# 270:	learn: 3.5799868	total: 3.28s	remaining: 8.81s
# 271:	learn: 3.5676159	total: 3.3s	remaining: 8.82s
# 272:	learn: 3.5607313	total: 3.31s	remaining: 8.81s
# 273:	learn: 3.5568587	total: 3.32s	remaining: 8.8s
# 274:	learn: 3.5521288	total: 3.33s	remaining: 8.78s
# 275:	learn: 3.5433391	total: 3.35s	remaining: 8.78s
# 276:	learn: 3.5338793	total: 3.36s	remaining: 8.76s
# 277:	learn: 3.5246077	total: 3.37s	remaining: 8.75s
# 278:	learn: 3.5162210	total: 3.38s	remaining: 8.74s
# 279:	learn: 3.5075906	total: 3.39s	remaining: 8.72s
# 280:	learn: 3.4975130	total: 3.41s	remaining: 8.72s
# 281:	learn: 3.4896191	total: 3.42s	remaining: 8.72s
# 282:	learn: 3.4841390	total: 3.44s	remaining: 8.73s
# 283:	learn: 3.4716587	total: 3.46s	remaining: 8.73s
# 284:	learn: 3.4622796	total: 3.47s	remaining: 8.71s
# 285:	learn: 3.4534578	total: 3.48s	remaining: 8.7s
# 286:	learn: 3.4456668	total: 3.5s	remaining: 8.69s
# 287:	learn: 3.4387558	total: 3.51s	remaining: 8.68s
# 288:	learn: 3.4243080	total: 3.52s	remaining: 8.67s
# 289:	learn: 3.4140559	total: 3.53s	remaining: 8.65s
# 290:	learn: 3.4018956	total: 3.54s	remaining: 8.63s
# 291:	learn: 3.3911030	total: 3.55s	remaining: 8.61s
# 292:	learn: 3.3741683	total: 3.56s	remaining: 8.59s
# 293:	learn: 3.3596439	total: 3.57s	remaining: 8.57s
# 294:	learn: 3.3478188	total: 3.58s	remaining: 8.55s
# 295:	learn: 3.3354254	total: 3.59s	remaining: 8.53s
# 296:	learn: 3.3263602	total: 3.6s	remaining: 8.51s
# 297:	learn: 3.3198157	total: 3.6s	remaining: 8.49s
# 298:	learn: 3.3100667	total: 3.62s	remaining: 8.49s
# 299:	learn: 3.3006452	total: 3.64s	remaining: 8.49s
# 300:	learn: 3.2793167	total: 3.65s	remaining: 8.47s
# 301:	learn: 3.2714724	total: 3.66s	remaining: 8.46s
# 302:	learn: 3.2641961	total: 3.67s	remaining: 8.45s
# 303:	learn: 3.2579727	total: 3.69s	remaining: 8.45s
# 304:	learn: 3.2499927	total: 3.71s	remaining: 8.44s
# 305:	learn: 3.2378595	total: 3.72s	remaining: 8.43s
# 306:	learn: 3.2305286	total: 3.75s	remaining: 8.47s
# 307:	learn: 3.2209251	total: 3.79s	remaining: 8.52s
# 308:	learn: 3.2140251	total: 3.83s	remaining: 8.56s
# 309:	learn: 3.2064741	total: 3.9s	remaining: 8.67s
# 310:	learn: 3.1955346	total: 4s	remaining: 8.85s
# 311:	learn: 3.1884872	total: 4.05s	remaining: 8.93s
# 312:	learn: 3.1817108	total: 4.07s	remaining: 8.92s
# 313:	learn: 3.1734997	total: 4.08s	remaining: 8.92s
# 314:	learn: 3.1650464	total: 4.1s	remaining: 8.91s
# 315:	learn: 3.1574236	total: 4.12s	remaining: 8.91s
# 316:	learn: 3.1531098	total: 4.14s	remaining: 8.91s
# 317:	learn: 3.1480955	total: 4.15s	remaining: 8.9s
# 318:	learn: 3.1412995	total: 4.17s	remaining: 8.89s
# 319:	learn: 3.1326986	total: 4.18s	remaining: 8.89s
# 320:	learn: 3.1207676	total: 4.2s	remaining: 8.88s
# 321:	learn: 3.1089723	total: 4.21s	remaining: 8.87s
# 322:	learn: 3.1025240	total: 4.22s	remaining: 8.86s
# 323:	learn: 3.0962650	total: 4.24s	remaining: 8.84s
# 324:	learn: 3.0899159	total: 4.25s	remaining: 8.82s
# 325:	learn: 3.0815914	total: 4.26s	remaining: 8.81s
# 326:	learn: 3.0737811	total: 4.28s	remaining: 8.81s
# 327:	learn: 3.0659742	total: 4.29s	remaining: 8.79s
# 328:	learn: 3.0513254	total: 4.3s	remaining: 8.78s
# 329:	learn: 3.0373425	total: 4.31s	remaining: 8.76s
# 330:	learn: 3.0250504	total: 4.33s	remaining: 8.74s
# 331:	learn: 3.0149925	total: 4.33s	remaining: 8.72s
# 332:	learn: 3.0050367	total: 4.34s	remaining: 8.7s
# 333:	learn: 2.9943646	total: 4.35s	remaining: 8.68s
# 334:	learn: 2.9831649	total: 4.36s	remaining: 8.66s
# 335:	learn: 2.9749879	total: 4.37s	remaining: 8.64s
# 336:	learn: 2.9706566	total: 4.38s	remaining: 8.62s
# 337:	learn: 2.9655424	total: 4.39s	remaining: 8.6s
# 338:	learn: 2.9587260	total: 4.41s	remaining: 8.6s
# 339:	learn: 2.9492352	total: 4.42s	remaining: 8.59s
# 340:	learn: 2.9409692	total: 4.44s	remaining: 8.57s
# 341:	learn: 2.9311817	total: 4.5s	remaining: 8.66s
# 342:	learn: 2.9251789	total: 4.53s	remaining: 8.67s
# 343:	learn: 2.9205259	total: 4.54s	remaining: 8.65s
# 344:	learn: 2.9151229	total: 4.55s	remaining: 8.64s
# 345:	learn: 2.9082717	total: 4.56s	remaining: 8.63s
# 346:	learn: 2.9026808	total: 4.58s	remaining: 8.62s
# 347:	learn: 2.8961827	total: 4.6s	remaining: 8.61s
# 348:	learn: 2.8832702	total: 4.61s	remaining: 8.6s
# 349:	learn: 2.8731550	total: 4.62s	remaining: 8.59s
# 350:	learn: 2.8671813	total: 4.64s	remaining: 8.57s
# 351:	learn: 2.8596350	total: 4.65s	remaining: 8.56s
# 352:	learn: 2.8555550	total: 4.66s	remaining: 8.54s
# 353:	learn: 2.8454391	total: 4.67s	remaining: 8.53s
# 354:	learn: 2.8366563	total: 4.68s	remaining: 8.51s
# 355:	learn: 2.8286633	total: 4.69s	remaining: 8.49s
# 356:	learn: 2.8208517	total: 4.7s	remaining: 8.47s
# 357:	learn: 2.8158752	total: 4.72s	remaining: 8.47s
# 358:	learn: 2.8063140	total: 4.74s	remaining: 8.46s
# 359:	learn: 2.7970544	total: 4.74s	remaining: 8.43s
# 360:	learn: 2.7902730	total: 4.75s	remaining: 8.42s
# 361:	learn: 2.7812597	total: 4.77s	remaining: 8.4s
# 362:	learn: 2.7698918	total: 4.78s	remaining: 8.38s
# 363:	learn: 2.7634763	total: 4.79s	remaining: 8.37s
# 364:	learn: 2.7541992	total: 4.81s	remaining: 8.36s
# 365:	learn: 2.7474775	total: 4.82s	remaining: 8.35s
# 366:	learn: 2.7373767	total: 4.83s	remaining: 8.33s
# 367:	learn: 2.7298243	total: 4.84s	remaining: 8.31s
# 368:	learn: 2.7236013	total: 4.84s	remaining: 8.29s
# 369:	learn: 2.7191684	total: 4.85s	remaining: 8.26s
# 370:	learn: 2.7105440	total: 4.87s	remaining: 8.26s
# 371:	learn: 2.7035077	total: 4.89s	remaining: 8.25s
# 372:	learn: 2.6970665	total: 4.9s	remaining: 8.24s
# 373:	learn: 2.6892154	total: 4.93s	remaining: 8.25s
# 374:	learn: 2.6833427	total: 4.95s	remaining: 8.25s
# 375:	learn: 2.6749651	total: 4.97s	remaining: 8.24s
# 376:	learn: 2.6691588	total: 4.98s	remaining: 8.22s
# 377:	learn: 2.6611528	total: 4.99s	remaining: 8.21s
# 378:	learn: 2.6537838	total: 5s	remaining: 8.19s
# 379:	learn: 2.6495690	total: 5.01s	remaining: 8.18s
# 380:	learn: 2.6406094	total: 5.03s	remaining: 8.17s
# 381:	learn: 2.6355512	total: 5.04s	remaining: 8.16s
# 382:	learn: 2.6297321	total: 5.06s	remaining: 8.15s
# 383:	learn: 2.6255202	total: 5.07s	remaining: 8.14s
# 384:	learn: 2.6190925	total: 5.1s	remaining: 8.15s
# 385:	learn: 2.6163299	total: 5.11s	remaining: 8.13s
# 386:	learn: 2.6100800	total: 5.14s	remaining: 8.14s
# 387:	learn: 2.6074191	total: 5.17s	remaining: 8.15s
# 388:	learn: 2.5997010	total: 5.18s	remaining: 8.14s
# 389:	learn: 2.5887226	total: 5.2s	remaining: 8.13s
# 390:	learn: 2.5804526	total: 5.22s	remaining: 8.13s
# 391:	learn: 2.5752313	total: 5.24s	remaining: 8.12s
# 392:	learn: 2.5672713	total: 5.25s	remaining: 8.12s
# 393:	learn: 2.5590004	total: 5.27s	remaining: 8.11s
# 394:	learn: 2.5536530	total: 5.29s	remaining: 8.1s
# 395:	learn: 2.5488619	total: 5.3s	remaining: 8.09s
# 396:	learn: 2.5407810	total: 5.32s	remaining: 8.08s
# 397:	learn: 2.5346033	total: 5.33s	remaining: 8.06s
# 398:	learn: 2.5277217	total: 5.35s	remaining: 8.06s
# 399:	learn: 2.5234277	total: 5.37s	remaining: 8.05s
# 400:	learn: 2.5173697	total: 5.39s	remaining: 8.06s
# 401:	learn: 2.5143540	total: 5.41s	remaining: 8.05s
# 402:	learn: 2.5077295	total: 5.43s	remaining: 8.04s
# 403:	learn: 2.5030538	total: 5.44s	remaining: 8.03s
# 404:	learn: 2.4963099	total: 5.46s	remaining: 8.01s
# 405:	learn: 2.4894503	total: 5.47s	remaining: 8s
# 406:	learn: 2.4830521	total: 5.48s	remaining: 7.98s
# 407:	learn: 2.4776703	total: 5.49s	remaining: 7.97s
# 408:	learn: 2.4734962	total: 5.51s	remaining: 7.96s
# 409:	learn: 2.4687316	total: 5.52s	remaining: 7.94s
# 410:	learn: 2.4655255	total: 5.53s	remaining: 7.93s
# 411:	learn: 2.4566227	total: 5.54s	remaining: 7.91s
# 412:	learn: 2.4501238	total: 5.55s	remaining: 7.89s
# 413:	learn: 2.4466015	total: 5.57s	remaining: 7.88s
# 414:	learn: 2.4391212	total: 5.59s	remaining: 7.88s
# 415:	learn: 2.4282439	total: 5.6s	remaining: 7.86s
# 416:	learn: 2.4235775	total: 5.61s	remaining: 7.84s
# 417:	learn: 2.4176925	total: 5.62s	remaining: 7.83s
# 418:	learn: 2.4121815	total: 5.63s	remaining: 7.81s
# 419:	learn: 2.4009296	total: 5.64s	remaining: 7.79s
# 420:	learn: 2.3944561	total: 5.65s	remaining: 7.77s
# 421:	learn: 2.3888346	total: 5.66s	remaining: 7.76s
# 422:	learn: 2.3845198	total: 5.67s	remaining: 7.74s
# 423:	learn: 2.3798059	total: 5.69s	remaining: 7.72s
# 424:	learn: 2.3712143	total: 5.7s	remaining: 7.72s
# 425:	learn: 2.3666052	total: 5.72s	remaining: 7.71s
# 426:	learn: 2.3596201	total: 5.74s	remaining: 7.7s
# 427:	learn: 2.3540288	total: 5.75s	remaining: 7.69s
# 428:	learn: 2.3476495	total: 5.79s	remaining: 7.71s
# 429:	learn: 2.3390950	total: 5.81s	remaining: 7.7s
# 430:	learn: 2.3351178	total: 5.82s	remaining: 7.69s
# 431:	learn: 2.3290279	total: 5.84s	remaining: 7.67s
# 432:	learn: 2.3217012	total: 5.86s	remaining: 7.67s
# 433:	learn: 2.3180802	total: 5.87s	remaining: 7.66s
# 434:	learn: 2.3137747	total: 5.89s	remaining: 7.64s
# 435:	learn: 2.3103718	total: 5.9s	remaining: 7.64s
# 436:	learn: 2.3048563	total: 6.01s	remaining: 7.75s
# 437:	learn: 2.2996424	total: 6.04s	remaining: 7.75s
# 438:	learn: 2.2931689	total: 6.06s	remaining: 7.74s
# 439:	learn: 2.2886215	total: 6.08s	remaining: 7.74s
# 440:	learn: 2.2812993	total: 6.1s	remaining: 7.73s
# 441:	learn: 2.2732323	total: 6.12s	remaining: 7.72s
# 442:	learn: 2.2676649	total: 6.13s	remaining: 7.71s
# 443:	learn: 2.2610444	total: 6.16s	remaining: 7.72s
# 444:	learn: 2.2551756	total: 6.23s	remaining: 7.77s
# 445:	learn: 2.2520707	total: 6.25s	remaining: 7.77s
# 446:	learn: 2.2482683	total: 6.27s	remaining: 7.76s
# 447:	learn: 2.2453734	total: 6.29s	remaining: 7.75s
# 448:	learn: 2.2364420	total: 6.3s	remaining: 7.73s
# 449:	learn: 2.2309304	total: 6.32s	remaining: 7.72s
# 450:	learn: 2.2263914	total: 6.33s	remaining: 7.71s
# 451:	learn: 2.2219465	total: 6.36s	remaining: 7.71s
# 452:	learn: 2.2175484	total: 6.4s	remaining: 7.73s
# 453:	learn: 2.2141668	total: 6.42s	remaining: 7.72s
# 454:	learn: 2.2095244	total: 6.44s	remaining: 7.71s
# 455:	learn: 2.1985012	total: 6.47s	remaining: 7.71s
# 456:	learn: 2.1955517	total: 6.49s	remaining: 7.71s
# 457:	learn: 2.1897784	total: 6.52s	remaining: 7.71s
# 458:	learn: 2.1859594	total: 6.54s	remaining: 7.7s
# 459:	learn: 2.1808247	total: 6.55s	remaining: 7.69s
# 460:	learn: 2.1807115	total: 6.57s	remaining: 7.68s
# 461:	learn: 2.1745926	total: 6.6s	remaining: 7.68s
# 462:	learn: 2.1722075	total: 6.62s	remaining: 7.68s
# 463:	learn: 2.1676107	total: 6.63s	remaining: 7.66s
# 464:	learn: 2.1639851	total: 6.66s	remaining: 7.66s
# 465:	learn: 2.1590843	total: 6.69s	remaining: 7.67s
# 466:	learn: 2.1554115	total: 6.71s	remaining: 7.65s
# 467:	learn: 2.1530369	total: 6.72s	remaining: 7.64s
# 468:	learn: 2.1478124	total: 6.74s	remaining: 7.63s
# 469:	learn: 2.1405016	total: 6.76s	remaining: 7.62s
# 470:	learn: 2.1361009	total: 6.79s	remaining: 7.63s
# 471:	learn: 2.1314803	total: 6.8s	remaining: 7.61s
# 472:	learn: 2.1271948	total: 6.82s	remaining: 7.6s
# 473:	learn: 2.1235298	total: 6.83s	remaining: 7.58s
# 474:	learn: 2.1185587	total: 6.85s	remaining: 7.57s
# 475:	learn: 2.1155277	total: 6.87s	remaining: 7.57s
# 476:	learn: 2.1108163	total: 6.9s	remaining: 7.57s
# 477:	learn: 2.1032637	total: 6.94s	remaining: 7.57s
# 478:	learn: 2.0982575	total: 6.96s	remaining: 7.57s
# 479:	learn: 2.0938572	total: 6.97s	remaining: 7.55s
# 480:	learn: 2.0898503	total: 6.99s	remaining: 7.54s
# 481:	learn: 2.0869824	total: 7.01s	remaining: 7.53s
# 482:	learn: 2.0835398	total: 7.03s	remaining: 7.52s
# 483:	learn: 2.0824483	total: 7.04s	remaining: 7.5s
# 484:	learn: 2.0781722	total: 7.05s	remaining: 7.49s
# 485:	learn: 2.0719572	total: 7.08s	remaining: 7.49s
# 486:	learn: 2.0672539	total: 7.1s	remaining: 7.48s
# 487:	learn: 2.0631398	total: 7.12s	remaining: 7.47s
# 488:	learn: 2.0582617	total: 7.13s	remaining: 7.46s
# 489:	learn: 2.0538437	total: 7.15s	remaining: 7.44s
# 490:	learn: 2.0508312	total: 7.17s	remaining: 7.43s
# 491:	learn: 2.0481366	total: 7.18s	remaining: 7.42s
# 492:	learn: 2.0408867	total: 7.2s	remaining: 7.4s
# 493:	learn: 2.0374484	total: 7.21s	remaining: 7.39s
# 494:	learn: 2.0323662	total: 7.23s	remaining: 7.37s
# 495:	learn: 2.0277750	total: 7.24s	remaining: 7.36s
# 496:	learn: 2.0234324	total: 7.26s	remaining: 7.34s
# 497:	learn: 2.0180102	total: 7.29s	remaining: 7.34s
# 498:	learn: 2.0156615	total: 7.33s	remaining: 7.35s
# 499:	learn: 2.0104085	total: 7.35s	remaining: 7.35s
# 500:	learn: 2.0045555	total: 7.37s	remaining: 7.34s
# 501:	learn: 1.9938311	total: 7.39s	remaining: 7.33s
# 502:	learn: 1.9890438	total: 7.4s	remaining: 7.31s
# 503:	learn: 1.9848061	total: 7.41s	remaining: 7.29s
# 504:	learn: 1.9799870	total: 7.43s	remaining: 7.28s
# 505:	learn: 1.9760692	total: 7.44s	remaining: 7.26s
# 506:	learn: 1.9702157	total: 7.45s	remaining: 7.25s
# 507:	learn: 1.9675341	total: 7.47s	remaining: 7.23s
# 508:	learn: 1.9646865	total: 7.49s	remaining: 7.23s
# 509:	learn: 1.9591908	total: 7.52s	remaining: 7.22s
# 510:	learn: 1.9538234	total: 7.54s	remaining: 7.21s
# 511:	learn: 1.9497560	total: 7.56s	remaining: 7.2s
# 512:	learn: 1.9462355	total: 7.57s	remaining: 7.19s
# 513:	learn: 1.9455287	total: 7.6s	remaining: 7.18s
# 514:	learn: 1.9425641	total: 7.61s	remaining: 7.17s
# 515:	learn: 1.9381389	total: 7.63s	remaining: 7.15s
# 516:	learn: 1.9322489	total: 7.64s	remaining: 7.14s
# 517:	learn: 1.9284518	total: 7.66s	remaining: 7.13s
# 518:	learn: 1.9246689	total: 7.67s	remaining: 7.11s
# 519:	learn: 1.9214369	total: 7.69s	remaining: 7.09s
# 520:	learn: 1.9173903	total: 7.71s	remaining: 7.09s
# 521:	learn: 1.9146093	total: 7.73s	remaining: 7.08s
# 522:	learn: 1.9087498	total: 7.75s	remaining: 7.07s
# 523:	learn: 1.9032728	total: 7.77s	remaining: 7.06s
# 524:	learn: 1.9000264	total: 7.78s	remaining: 7.04s
# 525:	learn: 1.8957269	total: 7.8s	remaining: 7.03s
# 526:	learn: 1.8919144	total: 7.82s	remaining: 7.02s
# 527:	learn: 1.8891227	total: 7.84s	remaining: 7.01s
# 528:	learn: 1.8863134	total: 7.86s	remaining: 7s
# 529:	learn: 1.8849031	total: 7.87s	remaining: 6.98s
# 530:	learn: 1.8820422	total: 7.88s	remaining: 6.96s
# 531:	learn: 1.8792619	total: 7.9s	remaining: 6.95s
# 532:	learn: 1.8771681	total: 7.92s	remaining: 6.93s
# 533:	learn: 1.8746991	total: 7.95s	remaining: 6.94s
# 534:	learn: 1.8703763	total: 7.97s	remaining: 6.92s
# 535:	learn: 1.8670549	total: 7.98s	remaining: 6.91s
# 536:	learn: 1.8629902	total: 7.99s	remaining: 6.89s
# 537:	learn: 1.8579017	total: 8.01s	remaining: 6.88s
# 538:	learn: 1.8526205	total: 8.02s	remaining: 6.86s
# 539:	learn: 1.8503186	total: 8.04s	remaining: 6.85s
# 540:	learn: 1.8455298	total: 8.06s	remaining: 6.84s
# 541:	learn: 1.8426490	total: 8.07s	remaining: 6.82s
# 542:	learn: 1.8357211	total: 8.09s	remaining: 6.81s
# 543:	learn: 1.8324302	total: 8.11s	remaining: 6.8s
# 544:	learn: 1.8297746	total: 8.14s	remaining: 6.8s
# 545:	learn: 1.8244558	total: 8.17s	remaining: 6.79s
# 546:	learn: 1.8231879	total: 8.19s	remaining: 6.78s
# 547:	learn: 1.8202124	total: 8.2s	remaining: 6.76s
# 548:	learn: 1.8137277	total: 8.21s	remaining: 6.75s
# 549:	learn: 1.8100836	total: 8.23s	remaining: 6.73s
# 550:	learn: 1.8055841	total: 8.25s	remaining: 6.72s
# 551:	learn: 1.8017412	total: 8.27s	remaining: 6.71s
# 552:	learn: 1.8001971	total: 8.29s	remaining: 6.7s
# 553:	learn: 1.7958832	total: 8.31s	remaining: 6.69s
# 554:	learn: 1.7939715	total: 8.33s	remaining: 6.68s
# 555:	learn: 1.7898228	total: 8.36s	remaining: 6.67s
# 556:	learn: 1.7850503	total: 8.39s	remaining: 6.67s
# 557:	learn: 1.7837992	total: 8.42s	remaining: 6.67s
# 558:	learn: 1.7806131	total: 8.44s	remaining: 6.66s
# 559:	learn: 1.7775299	total: 8.45s	remaining: 6.64s
# 560:	learn: 1.7744434	total: 8.47s	remaining: 6.63s
# 561:	learn: 1.7720973	total: 8.49s	remaining: 6.62s
# 562:	learn: 1.7691107	total: 8.51s	remaining: 6.6s
# 563:	learn: 1.7659757	total: 8.53s	remaining: 6.59s
# 564:	learn: 1.7629490	total: 8.54s	remaining: 6.58s
# 565:	learn: 1.7599306	total: 8.57s	remaining: 6.57s
# 566:	learn: 1.7553085	total: 8.64s	remaining: 6.59s
# 567:	learn: 1.7514590	total: 8.66s	remaining: 6.59s
# 568:	learn: 1.7489125	total: 8.68s	remaining: 6.57s
# 569:	learn: 1.7453981	total: 8.69s	remaining: 6.56s
# 570:	learn: 1.7420414	total: 8.71s	remaining: 6.54s
# 571:	learn: 1.7397854	total: 8.73s	remaining: 6.53s
# 572:	learn: 1.7339163	total: 8.76s	remaining: 6.53s
# 573:	learn: 1.7312349	total: 8.77s	remaining: 6.51s
# 574:	learn: 1.7289050	total: 8.81s	remaining: 6.51s
# 575:	learn: 1.7237583	total: 8.84s	remaining: 6.51s
# 576:	learn: 1.7209342	total: 8.86s	remaining: 6.5s
# 577:	learn: 1.7168927	total: 8.88s	remaining: 6.48s
# 578:	learn: 1.7143583	total: 8.89s	remaining: 6.46s
# 579:	learn: 1.7107046	total: 8.91s	remaining: 6.45s
# 580:	learn: 1.7080588	total: 8.92s	remaining: 6.43s
# 581:	learn: 1.7051420	total: 8.94s	remaining: 6.42s
# 582:	learn: 1.7016747	total: 8.96s	remaining: 6.41s
# 583:	learn: 1.6979837	total: 8.98s	remaining: 6.4s
# 584:	learn: 1.6945511	total: 9.04s	remaining: 6.41s
# 585:	learn: 1.6938610	total: 9.05s	remaining: 6.39s
# 586:	learn: 1.6891940	total: 9.06s	remaining: 6.38s
# 587:	learn: 1.6862194	total: 9.08s	remaining: 6.36s
# 588:	learn: 1.6833600	total: 9.1s	remaining: 6.35s
# 589:	learn: 1.6796394	total: 9.12s	remaining: 6.34s
# 590:	learn: 1.6770729	total: 9.14s	remaining: 6.32s
# 591:	learn: 1.6735112	total: 9.16s	remaining: 6.31s
# 592:	learn: 1.6682000	total: 9.18s	remaining: 6.3s
# 593:	learn: 1.6654636	total: 9.21s	remaining: 6.29s
# 594:	learn: 1.6610713	total: 9.24s	remaining: 6.29s
# 595:	learn: 1.6574355	total: 9.26s	remaining: 6.28s
# 596:	learn: 1.6544159	total: 9.27s	remaining: 6.26s
# 597:	learn: 1.6520982	total: 9.28s	remaining: 6.24s
# 598:	learn: 1.6476097	total: 9.3s	remaining: 6.22s
# 599:	learn: 1.6429094	total: 9.31s	remaining: 6.21s
# 600:	learn: 1.6380498	total: 9.33s	remaining: 6.19s
# 601:	learn: 1.6344488	total: 9.35s	remaining: 6.18s
# 602:	learn: 1.6274222	total: 9.38s	remaining: 6.17s
# 603:	learn: 1.6238119	total: 9.4s	remaining: 6.16s
# 604:	learn: 1.6204529	total: 9.41s	remaining: 6.14s
# 605:	learn: 1.6184882	total: 9.44s	remaining: 6.14s
# 606:	learn: 1.6153180	total: 9.47s	remaining: 6.13s
# 607:	learn: 1.6124976	total: 9.49s	remaining: 6.12s
# 608:	learn: 1.6087232	total: 9.51s	remaining: 6.1s
# 609:	learn: 1.6056667	total: 9.52s	remaining: 6.09s
# 610:	learn: 1.6021739	total: 9.54s	remaining: 6.07s
# 611:	learn: 1.5991287	total: 9.55s	remaining: 6.06s
# 612:	learn: 1.5973011	total: 9.57s	remaining: 6.04s
# 613:	learn: 1.5942297	total: 9.59s	remaining: 6.03s
# 614:	learn: 1.5925775	total: 9.61s	remaining: 6.01s
# 615:	learn: 1.5887026	total: 9.63s	remaining: 6s
# 616:	learn: 1.5853736	total: 9.66s	remaining: 6s
# 617:	learn: 1.5830231	total: 9.69s	remaining: 5.99s
# 618:	learn: 1.5808415	total: 9.71s	remaining: 5.98s
# 619:	learn: 1.5787656	total: 9.72s	remaining: 5.96s
# 620:	learn: 1.5787141	total: 9.74s	remaining: 5.94s
# 621:	learn: 1.5773254	total: 9.75s	remaining: 5.92s
# 622:	learn: 1.5751953	total: 9.76s	remaining: 5.91s
# 623:	learn: 1.5720752	total: 9.78s	remaining: 5.89s
# 624:	learn: 1.5692361	total: 9.79s	remaining: 5.88s
# 625:	learn: 1.5667046	total: 9.82s	remaining: 5.87s
# 626:	learn: 1.5646529	total: 9.84s	remaining: 5.85s
# 627:	learn: 1.5623661	total: 9.86s	remaining: 5.84s
# 628:	learn: 1.5602053	total: 9.87s	remaining: 5.82s
# 629:	learn: 1.5573742	total: 9.9s	remaining: 5.81s
# 630:	learn: 1.5544670	total: 9.96s	remaining: 5.82s
# 631:	learn: 1.5505937	total: 10s	remaining: 5.82s
# 632:	learn: 1.5481548	total: 10s	remaining: 5.8s
# 633:	learn: 1.5460848	total: 10s	remaining: 5.79s
# 634:	learn: 1.5439681	total: 10s	remaining: 5.77s
# 635:	learn: 1.5422160	total: 10.1s	remaining: 5.76s
# 636:	learn: 1.5375289	total: 10.1s	remaining: 5.75s
# 637:	learn: 1.5359905	total: 10.1s	remaining: 5.73s
# 638:	learn: 1.5341777	total: 10.1s	remaining: 5.72s
# 639:	learn: 1.5308424	total: 10.1s	remaining: 5.7s
# 640:	learn: 1.5275880	total: 10.2s	remaining: 5.69s
# 641:	learn: 1.5247401	total: 10.2s	remaining: 5.67s
# 642:	learn: 1.5225801	total: 10.2s	remaining: 5.66s
# 643:	learn: 1.5197998	total: 10.2s	remaining: 5.64s
# 644:	learn: 1.5159935	total: 10.2s	remaining: 5.63s
# 645:	learn: 1.5136515	total: 10.2s	remaining: 5.61s
# 646:	learn: 1.5116600	total: 10.3s	remaining: 5.6s
# 647:	learn: 1.5075242	total: 10.3s	remaining: 5.59s
# 648:	learn: 1.5047141	total: 10.3s	remaining: 5.58s
# 649:	learn: 1.5038919	total: 10.3s	remaining: 5.57s
# 650:	learn: 1.5025080	total: 10.4s	remaining: 5.55s
# 651:	learn: 1.4982651	total: 10.4s	remaining: 5.54s
# 652:	learn: 1.4960787	total: 10.4s	remaining: 5.52s
# 653:	learn: 1.4920872	total: 10.4s	remaining: 5.51s
# 654:	learn: 1.4903296	total: 10.4s	remaining: 5.49s
# 655:	learn: 1.4892000	total: 10.4s	remaining: 5.48s
# 656:	learn: 1.4868474	total: 10.5s	remaining: 5.46s
# 657:	learn: 1.4841639	total: 10.5s	remaining: 5.45s
# 658:	learn: 1.4794498	total: 10.5s	remaining: 5.43s
# 659:	learn: 1.4765276	total: 10.5s	remaining: 5.42s
# 660:	learn: 1.4744769	total: 10.6s	remaining: 5.41s
# 661:	learn: 1.4706779	total: 10.6s	remaining: 5.4s
# 662:	learn: 1.4691060	total: 10.6s	remaining: 5.38s
# 663:	learn: 1.4647730	total: 10.6s	remaining: 5.36s
# 664:	learn: 1.4634243	total: 10.6s	remaining: 5.34s
# 665:	learn: 1.4606659	total: 10.6s	remaining: 5.33s
# 666:	learn: 1.4572290	total: 10.6s	remaining: 5.32s
# 667:	learn: 1.4551334	total: 10.7s	remaining: 5.3s
# 668:	learn: 1.4524075	total: 10.7s	remaining: 5.29s
# 669:	learn: 1.4483544	total: 10.7s	remaining: 5.27s
# 670:	learn: 1.4448866	total: 10.7s	remaining: 5.25s
# 671:	learn: 1.4420879	total: 10.8s	remaining: 5.25s
# 672:	learn: 1.4396826	total: 10.8s	remaining: 5.24s
# 673:	learn: 1.4366103	total: 10.8s	remaining: 5.23s
# 674:	learn: 1.4348026	total: 10.8s	remaining: 5.21s
# 675:	learn: 1.4329798	total: 10.8s	remaining: 5.2s
# 676:	learn: 1.4304346	total: 10.9s	remaining: 5.18s
# 677:	learn: 1.4284084	total: 10.9s	remaining: 5.16s
# 678:	learn: 1.4260511	total: 10.9s	remaining: 5.15s
# 679:	learn: 1.4249641	total: 10.9s	remaining: 5.14s
# 680:	learn: 1.4210845	total: 10.9s	remaining: 5.12s
# 681:	learn: 1.4185415	total: 11s	remaining: 5.11s
# 682:	learn: 1.4164943	total: 11s	remaining: 5.09s
# 683:	learn: 1.4143023	total: 11s	remaining: 5.08s
# 684:	learn: 1.4111439	total: 11.1s	remaining: 5.12s
# 685:	learn: 1.4087272	total: 11.2s	remaining: 5.12s
# 686:	learn: 1.4059781	total: 11.2s	remaining: 5.12s
# 687:	learn: 1.4030835	total: 11.2s	remaining: 5.1s
# 688:	learn: 1.4018200	total: 11.3s	remaining: 5.08s
# 689:	learn: 1.3987631	total: 11.3s	remaining: 5.07s
# 690:	learn: 1.3964019	total: 11.3s	remaining: 5.06s
# 691:	learn: 1.3930813	total: 11.3s	remaining: 5.04s
# 692:	learn: 1.3899084	total: 11.3s	remaining: 5.02s
# 693:	learn: 1.3876617	total: 11.4s	remaining: 5.01s
# 694:	learn: 1.3855227	total: 11.4s	remaining: 4.99s
# 695:	learn: 1.3832285	total: 11.4s	remaining: 4.98s
# 696:	learn: 1.3816348	total: 11.4s	remaining: 4.97s
# 697:	learn: 1.3791831	total: 11.5s	remaining: 4.96s
# 698:	learn: 1.3749664	total: 11.5s	remaining: 4.95s
# 699:	learn: 1.3728392	total: 11.5s	remaining: 4.94s
# 700:	learn: 1.3704646	total: 11.6s	remaining: 4.93s
# 701:	learn: 1.3691573	total: 11.6s	remaining: 4.91s
# 702:	learn: 1.3662864	total: 11.6s	remaining: 4.9s
# 703:	learn: 1.3632927	total: 11.6s	remaining: 4.88s
# 704:	learn: 1.3616442	total: 11.6s	remaining: 4.86s
# 705:	learn: 1.3588907	total: 11.6s	remaining: 4.85s
# 706:	learn: 1.3567992	total: 11.7s	remaining: 4.83s
# 707:	learn: 1.3558553	total: 11.7s	remaining: 4.83s
# 708:	learn: 1.3519556	total: 11.8s	remaining: 4.83s
# 709:	learn: 1.3502229	total: 11.8s	remaining: 4.82s
# 710:	learn: 1.3480024	total: 11.8s	remaining: 4.81s
# 711:	learn: 1.3456483	total: 11.9s	remaining: 4.81s
# 712:	learn: 1.3436008	total: 11.9s	remaining: 4.79s
# 713:	learn: 1.3407733	total: 11.9s	remaining: 4.78s
# 714:	learn: 1.3386262	total: 11.9s	remaining: 4.76s
# 715:	learn: 1.3354612	total: 12s	remaining: 4.75s
# 716:	learn: 1.3338550	total: 12s	remaining: 4.73s
# 717:	learn: 1.3325782	total: 12s	remaining: 4.71s
# 718:	learn: 1.3298557	total: 12s	remaining: 4.7s
# 719:	learn: 1.3278607	total: 12s	remaining: 4.68s
# 720:	learn: 1.3261030	total: 12.1s	remaining: 4.66s
# 721:	learn: 1.3256631	total: 12.1s	remaining: 4.65s
# 722:	learn: 1.3220052	total: 12.1s	remaining: 4.64s
# 723:	learn: 1.3195588	total: 12.1s	remaining: 4.63s
# 724:	learn: 1.3177144	total: 12.2s	remaining: 4.61s
# 725:	learn: 1.3161316	total: 12.2s	remaining: 4.6s
# 726:	learn: 1.3145709	total: 12.2s	remaining: 4.58s
# 727:	learn: 1.3138234	total: 12.2s	remaining: 4.57s
# 728:	learn: 1.3128005	total: 12.3s	remaining: 4.56s
# 729:	learn: 1.3100840	total: 12.3s	remaining: 4.55s
# 730:	learn: 1.3084956	total: 12.3s	remaining: 4.54s
# 731:	learn: 1.3058219	total: 12.4s	remaining: 4.52s
# 732:	learn: 1.3041694	total: 12.4s	remaining: 4.51s
# 733:	learn: 1.3004623	total: 12.4s	remaining: 4.49s
# 734:	learn: 1.2990063	total: 12.4s	remaining: 4.48s
# 735:	learn: 1.2978561	total: 12.4s	remaining: 4.46s
# 736:	learn: 1.2966859	total: 12.5s	remaining: 4.45s
# 737:	learn: 1.2941701	total: 12.5s	remaining: 4.44s
# 738:	learn: 1.2922070	total: 12.5s	remaining: 4.42s
# 739:	learn: 1.2909635	total: 12.5s	remaining: 4.41s
# 740:	learn: 1.2885448	total: 12.6s	remaining: 4.39s
# 741:	learn: 1.2864862	total: 12.6s	remaining: 4.37s
# 742:	learn: 1.2843792	total: 12.6s	remaining: 4.36s
# 743:	learn: 1.2816241	total: 12.6s	remaining: 4.35s
# 744:	learn: 1.2798092	total: 12.7s	remaining: 4.33s
# 745:	learn: 1.2747721	total: 12.7s	remaining: 4.32s
# 746:	learn: 1.2728033	total: 12.7s	remaining: 4.3s
# 747:	learn: 1.2693230	total: 12.7s	remaining: 4.29s
# 748:	learn: 1.2678800	total: 12.8s	remaining: 4.28s
# 749:	learn: 1.2649970	total: 12.8s	remaining: 4.27s
# 750:	learn: 1.2619884	total: 12.8s	remaining: 4.25s
# 751:	learn: 1.2595352	total: 12.9s	remaining: 4.24s
# 752:	learn: 1.2568497	total: 12.9s	remaining: 4.23s
# 753:	learn: 1.2538505	total: 12.9s	remaining: 4.22s
# 754:	learn: 1.2522331	total: 12.9s	remaining: 4.2s
# 755:	learn: 1.2489648	total: 13s	remaining: 4.19s
# 756:	learn: 1.2461285	total: 13s	remaining: 4.17s
# 757:	learn: 1.2435354	total: 13s	remaining: 4.16s
# 758:	learn: 1.2413309	total: 13s	remaining: 4.14s
# 759:	learn: 1.2396394	total: 13.1s	remaining: 4.12s
# 760:	learn: 1.2372960	total: 13.1s	remaining: 4.11s
# 761:	learn: 1.2319982	total: 13.1s	remaining: 4.09s
# 762:	learn: 1.2297967	total: 13.2s	remaining: 4.09s
# 763:	learn: 1.2278016	total: 13.2s	remaining: 4.07s
# 764:	learn: 1.2254748	total: 13.2s	remaining: 4.06s
# 765:	learn: 1.2232407	total: 13.3s	remaining: 4.05s
# 766:	learn: 1.2213164	total: 13.3s	remaining: 4.03s
# 767:	learn: 1.2183132	total: 13.3s	remaining: 4.01s
# 768:	learn: 1.2161763	total: 13.3s	remaining: 4s
# 769:	learn: 1.2147675	total: 13.3s	remaining: 3.98s
# 770:	learn: 1.2117124	total: 13.3s	remaining: 3.96s
# 771:	learn: 1.2088733	total: 13.4s	remaining: 3.95s
# 772:	learn: 1.2078584	total: 13.4s	remaining: 3.94s
# 773:	learn: 1.2068022	total: 13.4s	remaining: 3.92s
# 774:	learn: 1.2055159	total: 13.4s	remaining: 3.9s
# 775:	learn: 1.2032790	total: 13.5s	remaining: 3.89s
# 776:	learn: 1.2000720	total: 13.5s	remaining: 3.87s
# 777:	learn: 1.1976782	total: 13.5s	remaining: 3.86s
# 778:	learn: 1.1958325	total: 13.6s	remaining: 3.85s
# 779:	learn: 1.1941795	total: 13.6s	remaining: 3.83s
# 780:	learn: 1.1921870	total: 13.8s	remaining: 3.87s
# 781:	learn: 1.1893023	total: 13.8s	remaining: 3.85s
# 782:	learn: 1.1868955	total: 13.8s	remaining: 3.83s
# 783:	learn: 1.1861032	total: 13.9s	remaining: 3.82s
# 784:	learn: 1.1834637	total: 13.9s	remaining: 3.81s
# 785:	learn: 1.1817993	total: 13.9s	remaining: 3.79s
# 786:	learn: 1.1799915	total: 13.9s	remaining: 3.77s
# 787:	learn: 1.1779304	total: 14s	remaining: 3.75s
# 788:	learn: 1.1758540	total: 14s	remaining: 3.74s
# 789:	learn: 1.1741093	total: 14s	remaining: 3.72s
# 790:	learn: 1.1714718	total: 14s	remaining: 3.7s
# 791:	learn: 1.1684263	total: 14s	remaining: 3.69s
# 792:	learn: 1.1671562	total: 14.1s	remaining: 3.67s
# 793:	learn: 1.1655648	total: 14.1s	remaining: 3.65s
# 794:	learn: 1.1634850	total: 14.1s	remaining: 3.64s
# 795:	learn: 1.1617926	total: 14.2s	remaining: 3.63s
# 796:	learn: 1.1607677	total: 14.2s	remaining: 3.61s
# 797:	learn: 1.1600999	total: 14.2s	remaining: 3.6s
# 798:	learn: 1.1576696	total: 14.3s	remaining: 3.58s
# 799:	learn: 1.1558284	total: 14.3s	remaining: 3.57s
# 800:	learn: 1.1537946	total: 14.3s	remaining: 3.55s
# 801:	learn: 1.1518175	total: 14.3s	remaining: 3.54s
# 802:	learn: 1.1500141	total: 14.3s	remaining: 3.52s
# 803:	learn: 1.1476293	total: 14.4s	remaining: 3.5s
# 804:	learn: 1.1457841	total: 14.4s	remaining: 3.48s
# 805:	learn: 1.1436302	total: 14.4s	remaining: 3.47s
# 806:	learn: 1.1417130	total: 14.4s	remaining: 3.45s
# 807:	learn: 1.1398578	total: 14.4s	remaining: 3.43s
# 808:	learn: 1.1383475	total: 14.5s	remaining: 3.42s
# 809:	learn: 1.1370198	total: 14.5s	remaining: 3.4s
# 810:	learn: 1.1329635	total: 14.5s	remaining: 3.39s
# 811:	learn: 1.1304339	total: 14.6s	remaining: 3.37s
# 812:	learn: 1.1295417	total: 14.6s	remaining: 3.35s
# 813:	learn: 1.1280664	total: 14.6s	remaining: 3.33s
# 814:	learn: 1.1263394	total: 14.6s	remaining: 3.32s
# 815:	learn: 1.1243024	total: 14.7s	remaining: 3.3s
# 816:	learn: 1.1232058	total: 14.7s	remaining: 3.29s
# 817:	learn: 1.1213427	total: 14.7s	remaining: 3.27s
# 818:	learn: 1.1187799	total: 14.7s	remaining: 3.25s
# 819:	learn: 1.1166291	total: 14.7s	remaining: 3.23s
# 820:	learn: 1.1143644	total: 14.8s	remaining: 3.22s
# 821:	learn: 1.1119019	total: 14.8s	remaining: 3.2s
# 822:	learn: 1.1098492	total: 14.8s	remaining: 3.18s
# 823:	learn: 1.1084030	total: 14.8s	remaining: 3.17s
# 824:	learn: 1.1077094	total: 14.8s	remaining: 3.15s
# 825:	learn: 1.1065804	total: 14.9s	remaining: 3.13s
# 826:	learn: 1.1049139	total: 14.9s	remaining: 3.11s
# 827:	learn: 1.1029781	total: 14.9s	remaining: 3.1s
# 828:	learn: 1.1016410	total: 14.9s	remaining: 3.08s
# 829:	learn: 1.0991326	total: 15s	remaining: 3.07s
# 830:	learn: 1.0969085	total: 15s	remaining: 3.05s
# 831:	learn: 1.0945915	total: 15s	remaining: 3.03s
# 832:	learn: 1.0923483	total: 15.1s	remaining: 3.02s
# 833:	learn: 1.0910570	total: 15.1s	remaining: 3s
# 834:	learn: 1.0898220	total: 15.1s	remaining: 2.98s
# 835:	learn: 1.0883622	total: 15.1s	remaining: 2.97s
# 836:	learn: 1.0868247	total: 15.1s	remaining: 2.95s
# 837:	learn: 1.0843450	total: 15.2s	remaining: 2.93s
# 838:	learn: 1.0828229	total: 15.2s	remaining: 2.91s
# 839:	learn: 1.0811904	total: 15.2s	remaining: 2.9s
# 840:	learn: 1.0791689	total: 15.2s	remaining: 2.88s
# 841:	learn: 1.0766603	total: 15.2s	remaining: 2.86s
# 842:	learn: 1.0749317	total: 15.3s	remaining: 2.84s
# 843:	learn: 1.0731574	total: 15.3s	remaining: 2.82s
# 844:	learn: 1.0694333	total: 15.3s	remaining: 2.81s
# 845:	learn: 1.0677209	total: 15.3s	remaining: 2.79s
# 846:	learn: 1.0654410	total: 15.4s	remaining: 2.77s
# 847:	learn: 1.0637195	total: 15.4s	remaining: 2.76s
# 848:	learn: 1.0614839	total: 15.4s	remaining: 2.74s
# 849:	learn: 1.0607713	total: 15.4s	remaining: 2.72s
# 850:	learn: 1.0595444	total: 15.5s	remaining: 2.71s
# 851:	learn: 1.0580882	total: 15.5s	remaining: 2.69s
# 852:	learn: 1.0564479	total: 15.5s	remaining: 2.67s
# 853:	learn: 1.0558860	total: 15.5s	remaining: 2.65s
# 854:	learn: 1.0543360	total: 15.6s	remaining: 2.64s
# 855:	learn: 1.0532972	total: 15.6s	remaining: 2.62s
# 856:	learn: 1.0519211	total: 15.6s	remaining: 2.6s
# 857:	learn: 1.0496193	total: 15.6s	remaining: 2.58s
# 858:	learn: 1.0485890	total: 15.6s	remaining: 2.56s
# 859:	learn: 1.0471607	total: 15.6s	remaining: 2.55s
# 860:	learn: 1.0453027	total: 15.7s	remaining: 2.53s
# 861:	learn: 1.0430415	total: 15.7s	remaining: 2.51s
# 862:	learn: 1.0410913	total: 15.7s	remaining: 2.5s
# 863:	learn: 1.0398389	total: 15.8s	remaining: 2.48s
# 864:	learn: 1.0390556	total: 15.8s	remaining: 2.46s
# 865:	learn: 1.0366382	total: 15.8s	remaining: 2.44s
# 866:	learn: 1.0348646	total: 15.8s	remaining: 2.43s
# 867:	learn: 1.0335330	total: 15.8s	remaining: 2.41s
# 868:	learn: 1.0325641	total: 15.8s	remaining: 2.39s
# 869:	learn: 1.0316012	total: 15.9s	remaining: 2.37s
# 870:	learn: 1.0293750	total: 15.9s	remaining: 2.35s
# 871:	learn: 1.0282121	total: 15.9s	remaining: 2.33s
# 872:	learn: 1.0263398	total: 15.9s	remaining: 2.32s
# 873:	learn: 1.0246919	total: 16s	remaining: 2.3s
# 874:	learn: 1.0224981	total: 16s	remaining: 2.28s
# 875:	learn: 1.0206637	total: 16s	remaining: 2.27s
# 876:	learn: 1.0184172	total: 16s	remaining: 2.25s
# 877:	learn: 1.0169844	total: 16s	remaining: 2.23s
# 878:	learn: 1.0151120	total: 16.1s	remaining: 2.21s
# 879:	learn: 1.0137487	total: 16.1s	remaining: 2.19s
# 880:	learn: 1.0119129	total: 16.1s	remaining: 2.17s
# 881:	learn: 1.0108452	total: 16.1s	remaining: 2.16s
# 882:	learn: 1.0093954	total: 16.1s	remaining: 2.14s
# 883:	learn: 1.0082221	total: 16.2s	remaining: 2.12s
# 884:	learn: 1.0068353	total: 16.2s	remaining: 2.1s
# 885:	learn: 1.0053289	total: 16.2s	remaining: 2.09s
# 886:	learn: 1.0037650	total: 16.2s	remaining: 2.07s
# 887:	learn: 1.0027768	total: 16.2s	remaining: 2.05s
# 888:	learn: 1.0016510	total: 16.3s	remaining: 2.03s
# 889:	learn: 1.0003246	total: 16.3s	remaining: 2.01s
# 890:	learn: 0.9987573	total: 16.3s	remaining: 1.99s
# 891:	learn: 0.9979535	total: 16.3s	remaining: 1.98s
# 892:	learn: 0.9971861	total: 16.3s	remaining: 1.96s
# 893:	learn: 0.9960313	total: 16.4s	remaining: 1.94s
# 894:	learn: 0.9952991	total: 16.4s	remaining: 1.92s
# 895:	learn: 0.9939729	total: 16.4s	remaining: 1.91s
# 896:	learn: 0.9928182	total: 16.5s	remaining: 1.89s
# 897:	learn: 0.9904669	total: 16.5s	remaining: 1.88s
# 898:	learn: 0.9883148	total: 16.6s	remaining: 1.86s
# 899:	learn: 0.9871938	total: 16.7s	remaining: 1.85s
# 900:	learn: 0.9853022	total: 16.7s	remaining: 1.84s
# 901:	learn: 0.9837042	total: 16.8s	remaining: 1.82s
# 902:	learn: 0.9826146	total: 16.8s	remaining: 1.8s
# 903:	learn: 0.9814740	total: 16.8s	remaining: 1.78s
# 904:	learn: 0.9803493	total: 16.8s	remaining: 1.76s
# 905:	learn: 0.9783786	total: 16.8s	remaining: 1.75s
# 906:	learn: 0.9769498	total: 16.9s	remaining: 1.73s
# 907:	learn: 0.9753982	total: 16.9s	remaining: 1.71s
# 908:	learn: 0.9725904	total: 16.9s	remaining: 1.69s
# 909:	learn: 0.9699979	total: 16.9s	remaining: 1.67s
# 910:	learn: 0.9686203	total: 16.9s	remaining: 1.65s
# 911:	learn: 0.9673243	total: 16.9s	remaining: 1.63s
# 912:	learn: 0.9664017	total: 17s	remaining: 1.61s
# 913:	learn: 0.9649366	total: 17s	remaining: 1.6s
# 914:	learn: 0.9633802	total: 17s	remaining: 1.58s
# 915:	learn: 0.9618741	total: 17s	remaining: 1.56s
# 916:	learn: 0.9608764	total: 17s	remaining: 1.54s
# 917:	learn: 0.9602907	total: 17s	remaining: 1.52s
# 918:	learn: 0.9593039	total: 17.1s	remaining: 1.5s
# 919:	learn: 0.9579028	total: 17.1s	remaining: 1.49s
# 920:	learn: 0.9568545	total: 17.2s	remaining: 1.48s
# 921:	learn: 0.9547925	total: 17.3s	remaining: 1.46s
# 922:	learn: 0.9535413	total: 17.3s	remaining: 1.44s
# 923:	learn: 0.9519859	total: 17.3s	remaining: 1.43s
# 924:	learn: 0.9511242	total: 17.4s	remaining: 1.41s
# 925:	learn: 0.9493046	total: 17.4s	remaining: 1.39s
# 926:	learn: 0.9489062	total: 17.4s	remaining: 1.37s
# 927:	learn: 0.9466632	total: 17.4s	remaining: 1.35s
# ...
# 691:	learn: 0.0474523	total: 11.3s	remaining: 5.04s
# 692:	learn: 0.0473434	total: 11.3s	remaining: 5.02s
# 693:	learn: 0.0472495	total: 11.3s	remaining: 5s
# 694:	learn: 0.0470957	total: 11.4s	remaining: 4.98s
# 695:	learn: 0.0470005	total: 11.4s	remaining: 4.97s
# 696:	learn: 0.0469189	total: 11.4s	remaining: 4.95s
# 697:	learn: 0.0468388	total: 11.4s	remaining: 4.93s
# 698:	learn: 0.0467706	total: 11.4s	remaining: 4.91s
# 699:	learn: 0.0466551	total: 11.4s	remaining: 4.9s
# 700:	learn: 0.0465805	total: 11.4s	remaining: 4.88s
# 701:	learn: 0.0464579	total: 11.5s	remaining: 4.86s
# 702:	learn: 0.0463369	total: 11.5s	remaining: 4.84s
# 703:	learn: 0.0462815	total: 11.5s	remaining: 4.83s
# 704:	learn: 0.0461169	total: 11.5s	remaining: 4.81s
# 705:	learn: 0.0459788	total: 11.5s	remaining: 4.8s
# 706:	learn: 0.0459191	total: 11.6s	remaining: 4.8s
# 707:	learn: 0.0458638	total: 11.6s	remaining: 4.79s
# 708:	learn: 0.0457670	total: 11.6s	remaining: 4.78s
# 709:	learn: 0.0456402	total: 11.7s	remaining: 4.76s
# 710:	learn: 0.0455466	total: 11.7s	remaining: 4.74s
# 711:	learn: 0.0454684	total: 11.7s	remaining: 4.73s
# 712:	learn: 0.0453985	total: 11.7s	remaining: 4.72s
# 713:	learn: 0.0453341	total: 11.7s	remaining: 4.7s
# 714:	learn: 0.0452742	total: 11.8s	remaining: 4.69s
# 715:	learn: 0.0451973	total: 11.8s	remaining: 4.68s
# 716:	learn: 0.0451236	total: 11.8s	remaining: 4.66s
# 717:	learn: 0.0449730	total: 11.9s	remaining: 4.65s
# 718:	learn: 0.0448831	total: 11.9s	remaining: 4.64s
# 719:	learn: 0.0447254	total: 11.9s	remaining: 4.63s
# 720:	learn: 0.0446596	total: 11.9s	remaining: 4.62s
# 721:	learn: 0.0445251	total: 11.9s	remaining: 4.6s
# 722:	learn: 0.0444344	total: 12s	remaining: 4.59s
# 723:	learn: 0.0442664	total: 12s	remaining: 4.57s
# 724:	learn: 0.0442019	total: 12s	remaining: 4.56s
# 725:	learn: 0.0440796	total: 12.1s	remaining: 4.55s
# 726:	learn: 0.0440269	total: 12.1s	remaining: 4.54s
# 727:	learn: 0.0439183	total: 12.1s	remaining: 4.53s
# 728:	learn: 0.0438693	total: 12.1s	remaining: 4.51s
# 729:	learn: 0.0437984	total: 12.2s	remaining: 4.5s
# 730:	learn: 0.0437107	total: 12.2s	remaining: 4.48s
# 731:	learn: 0.0436429	total: 12.2s	remaining: 4.46s
# 732:	learn: 0.0435893	total: 12.2s	remaining: 4.44s
# 733:	learn: 0.0435097	total: 12.2s	remaining: 4.43s
# 734:	learn: 0.0434637	total: 12.2s	remaining: 4.41s
# 735:	learn: 0.0433699	total: 12.3s	remaining: 4.39s
# 736:	learn: 0.0432760	total: 12.3s	remaining: 4.38s
# 737:	learn: 0.0431870	total: 12.3s	remaining: 4.36s
# 738:	learn: 0.0431101	total: 12.3s	remaining: 4.34s
# 739:	learn: 0.0430494	total: 12.3s	remaining: 4.33s
# 740:	learn: 0.0429549	total: 12.3s	remaining: 4.31s
# 741:	learn: 0.0429160	total: 12.3s	remaining: 4.29s
# 742:	learn: 0.0428698	total: 12.4s	remaining: 4.28s
# 743:	learn: 0.0428673	total: 12.4s	remaining: 4.26s
# 744:	learn: 0.0427526	total: 12.4s	remaining: 4.24s
# 745:	learn: 0.0426976	total: 12.4s	remaining: 4.23s
# 746:	learn: 0.0426167	total: 12.4s	remaining: 4.21s
# 747:	learn: 0.0425597	total: 12.4s	remaining: 4.19s
# 748:	learn: 0.0424815	total: 12.5s	remaining: 4.17s
# 749:	learn: 0.0424264	total: 12.5s	remaining: 4.16s
# 750:	learn: 0.0423812	total: 12.5s	remaining: 4.14s
# 751:	learn: 0.0423268	total: 12.5s	remaining: 4.12s
# 752:	learn: 0.0422694	total: 12.5s	remaining: 4.1s
# 753:	learn: 0.0421866	total: 12.5s	remaining: 4.09s
# 754:	learn: 0.0420216	total: 12.5s	remaining: 4.07s
# 755:	learn: 0.0419478	total: 12.6s	remaining: 4.05s
# 756:	learn: 0.0418694	total: 12.6s	remaining: 4.03s
# 757:	learn: 0.0417936	total: 12.6s	remaining: 4.01s
# 758:	learn: 0.0417191	total: 12.6s	remaining: 4s
# 759:	learn: 0.0417062	total: 12.6s	remaining: 3.98s
# 760:	learn: 0.0415702	total: 12.6s	remaining: 3.96s
# 761:	learn: 0.0414644	total: 12.6s	remaining: 3.94s
# 762:	learn: 0.0413877	total: 12.6s	remaining: 3.93s
# 763:	learn: 0.0413283	total: 12.7s	remaining: 3.91s
# 764:	learn: 0.0412700	total: 12.7s	remaining: 3.89s
# 765:	learn: 0.0412273	total: 12.7s	remaining: 3.87s
# 766:	learn: 0.0411624	total: 12.7s	remaining: 3.85s
# 767:	learn: 0.0411003	total: 12.7s	remaining: 3.84s
# 768:	learn: 0.0410091	total: 12.7s	remaining: 3.82s
# 769:	learn: 0.0409318	total: 12.7s	remaining: 3.8s
# 770:	learn: 0.0408346	total: 12.8s	remaining: 3.79s
# 771:	learn: 0.0407989	total: 12.8s	remaining: 3.77s
# 772:	learn: 0.0407445	total: 12.8s	remaining: 3.76s
# 773:	learn: 0.0407056	total: 12.8s	remaining: 3.74s
# 774:	learn: 0.0406328	total: 12.8s	remaining: 3.72s
# 775:	learn: 0.0405566	total: 12.8s	remaining: 3.7s
# 776:	learn: 0.0404652	total: 12.8s	remaining: 3.69s
# 777:	learn: 0.0403922	total: 12.9s	remaining: 3.67s
# 778:	learn: 0.0403098	total: 12.9s	remaining: 3.65s
# 779:	learn: 0.0402465	total: 12.9s	remaining: 3.63s
# 780:	learn: 0.0402029	total: 12.9s	remaining: 3.62s
# 781:	learn: 0.0401370	total: 12.9s	remaining: 3.6s
# 782:	learn: 0.0400493	total: 12.9s	remaining: 3.58s
# 783:	learn: 0.0399929	total: 12.9s	remaining: 3.56s
# 784:	learn: 0.0399107	total: 12.9s	remaining: 3.54s
# 785:	learn: 0.0398536	total: 13s	remaining: 3.53s
# 786:	learn: 0.0397905	total: 13s	remaining: 3.51s
# 787:	learn: 0.0397369	total: 13s	remaining: 3.49s
# 788:	learn: 0.0396765	total: 13s	remaining: 3.48s
# 789:	learn: 0.0395991	total: 13s	remaining: 3.46s
# 790:	learn: 0.0395395	total: 13s	remaining: 3.44s
# 791:	learn: 0.0394363	total: 13s	remaining: 3.42s
# 792:	learn: 0.0393163	total: 13.1s	remaining: 3.41s
# 793:	learn: 0.0392411	total: 13.1s	remaining: 3.39s
# 794:	learn: 0.0391716	total: 13.1s	remaining: 3.37s
# 795:	learn: 0.0391075	total: 13.1s	remaining: 3.35s
# 796:	learn: 0.0390401	total: 13.1s	remaining: 3.34s
# 797:	learn: 0.0389466	total: 13.1s	remaining: 3.32s
# 798:	learn: 0.0389151	total: 13.1s	remaining: 3.3s
# 799:	learn: 0.0388120	total: 13.1s	remaining: 3.29s
# 800:	learn: 0.0387432	total: 13.2s	remaining: 3.27s
# 801:	learn: 0.0386451	total: 13.2s	remaining: 3.25s
# 802:	learn: 0.0385890	total: 13.2s	remaining: 3.23s
# 803:	learn: 0.0385303	total: 13.2s	remaining: 3.22s
# 804:	learn: 0.0384407	total: 13.2s	remaining: 3.2s
# 805:	learn: 0.0383972	total: 13.2s	remaining: 3.18s
# 806:	learn: 0.0383531	total: 13.2s	remaining: 3.17s
# 807:	learn: 0.0383207	total: 13.3s	remaining: 3.15s
# 808:	learn: 0.0382179	total: 13.3s	remaining: 3.13s
# 809:	learn: 0.0381421	total: 13.3s	remaining: 3.11s
# 810:	learn: 0.0380453	total: 13.3s	remaining: 3.1s
# 811:	learn: 0.0379832	total: 13.3s	remaining: 3.08s
# 812:	learn: 0.0379290	total: 13.3s	remaining: 3.06s
# 813:	learn: 0.0378911	total: 13.3s	remaining: 3.04s
# 814:	learn: 0.0378257	total: 13.3s	remaining: 3.03s
# 815:	learn: 0.0377423	total: 13.4s	remaining: 3.01s
# 816:	learn: 0.0376665	total: 13.4s	remaining: 2.99s
# 817:	learn: 0.0375702	total: 13.4s	remaining: 2.99s
# 818:	learn: 0.0374961	total: 13.5s	remaining: 2.97s
# 819:	learn: 0.0374119	total: 13.5s	remaining: 2.96s
# 820:	learn: 0.0373620	total: 13.5s	remaining: 2.94s
# 821:	learn: 0.0372973	total: 13.5s	remaining: 2.92s
# 822:	learn: 0.0372418	total: 13.5s	remaining: 2.91s
# 823:	learn: 0.0371888	total: 13.5s	remaining: 2.89s
# 824:	learn: 0.0371587	total: 13.5s	remaining: 2.87s
# 825:	learn: 0.0371072	total: 13.6s	remaining: 2.85s
# 826:	learn: 0.0370060	total: 13.6s	remaining: 2.84s
# 827:	learn: 0.0369611	total: 13.6s	remaining: 2.82s
# 828:	learn: 0.0369123	total: 13.6s	remaining: 2.8s
# 829:	learn: 0.0368210	total: 13.6s	remaining: 2.79s
# 830:	learn: 0.0367456	total: 13.6s	remaining: 2.77s
# 831:	learn: 0.0367121	total: 13.6s	remaining: 2.75s
# 832:	learn: 0.0366527	total: 13.6s	remaining: 2.73s
# 833:	learn: 0.0365752	total: 13.7s	remaining: 2.72s
# 834:	learn: 0.0364746	total: 13.7s	remaining: 2.7s
# 835:	learn: 0.0364028	total: 13.7s	remaining: 2.69s
# 836:	learn: 0.0363033	total: 13.7s	remaining: 2.67s
# 837:	learn: 0.0362657	total: 13.7s	remaining: 2.65s
# 838:	learn: 0.0362131	total: 13.7s	remaining: 2.63s
# 839:	learn: 0.0361329	total: 13.7s	remaining: 2.62s
# 840:	learn: 0.0360895	total: 13.8s	remaining: 2.6s
# 841:	learn: 0.0360184	total: 13.8s	remaining: 2.58s
# 842:	learn: 0.0359631	total: 13.8s	remaining: 2.57s
# 843:	learn: 0.0358646	total: 13.8s	remaining: 2.55s
# 844:	learn: 0.0358045	total: 13.8s	remaining: 2.53s
# 845:	learn: 0.0357372	total: 13.8s	remaining: 2.52s
# 846:	learn: 0.0356772	total: 13.8s	remaining: 2.5s
# 847:	learn: 0.0356063	total: 13.8s	remaining: 2.48s
# 848:	learn: 0.0355478	total: 13.9s	remaining: 2.46s
# 849:	learn: 0.0354940	total: 13.9s	remaining: 2.45s
# 850:	learn: 0.0353668	total: 13.9s	remaining: 2.43s
# 851:	learn: 0.0352843	total: 13.9s	remaining: 2.41s
# 852:	learn: 0.0352495	total: 13.9s	remaining: 2.4s
# 853:	learn: 0.0352044	total: 13.9s	remaining: 2.38s
# 854:	learn: 0.0351601	total: 13.9s	remaining: 2.36s
# 855:	learn: 0.0350771	total: 14s	remaining: 2.35s
# 856:	learn: 0.0350250	total: 14s	remaining: 2.33s
# 857:	learn: 0.0349746	total: 14s	remaining: 2.31s
# 858:	learn: 0.0349272	total: 14s	remaining: 2.3s
# 859:	learn: 0.0348806	total: 14s	remaining: 2.28s
# 860:	learn: 0.0348515	total: 14s	remaining: 2.27s
# 861:	learn: 0.0347832	total: 14.1s	remaining: 2.25s
# 862:	learn: 0.0347166	total: 14.1s	remaining: 2.23s
# 863:	learn: 0.0346704	total: 14.1s	remaining: 2.22s
# 864:	learn: 0.0346215	total: 14.1s	remaining: 2.2s
# 865:	learn: 0.0345360	total: 14.1s	remaining: 2.18s
# 866:	learn: 0.0344580	total: 14.1s	remaining: 2.17s
# 867:	learn: 0.0344006	total: 14.1s	remaining: 2.15s
# 868:	learn: 0.0343446	total: 14.2s	remaining: 2.13s
# 869:	learn: 0.0342982	total: 14.2s	remaining: 2.12s
# 870:	learn: 0.0342358	total: 14.2s	remaining: 2.1s
# 871:	learn: 0.0342156	total: 14.2s	remaining: 2.09s
# 872:	learn: 0.0341814	total: 14.3s	remaining: 2.08s
# 873:	learn: 0.0341429	total: 14.4s	remaining: 2.07s
# 874:	learn: 0.0340858	total: 14.4s	remaining: 2.06s
# 875:	learn: 0.0340359	total: 14.4s	remaining: 2.04s
# 876:	learn: 0.0339877	total: 14.5s	remaining: 2.03s
# 877:	learn: 0.0339332	total: 14.5s	remaining: 2.02s
# 878:	learn: 0.0338801	total: 14.5s	remaining: 2s
# 879:	learn: 0.0338437	total: 14.6s	remaining: 1.98s
# 880:	learn: 0.0337998	total: 14.6s	remaining: 1.97s
# 881:	learn: 0.0337335	total: 14.6s	remaining: 1.96s
# 882:	learn: 0.0336841	total: 14.7s	remaining: 1.95s
# 883:	learn: 0.0336174	total: 14.7s	remaining: 1.93s
# 884:	learn: 0.0335739	total: 14.7s	remaining: 1.91s
# 885:	learn: 0.0335006	total: 14.7s	remaining: 1.89s
# 886:	learn: 0.0334246	total: 14.8s	remaining: 1.88s
# 887:	learn: 0.0333665	total: 14.8s	remaining: 1.87s
# 888:	learn: 0.0333143	total: 14.8s	remaining: 1.85s
# 889:	learn: 0.0332328	total: 14.9s	remaining: 1.84s
# 890:	learn: 0.0331490	total: 14.9s	remaining: 1.83s
# 891:	learn: 0.0331005	total: 15s	remaining: 1.81s
# 892:	learn: 0.0330428	total: 15s	remaining: 1.8s
# 893:	learn: 0.0329847	total: 15s	remaining: 1.78s
# 894:	learn: 0.0329263	total: 15.1s	remaining: 1.77s
# 895:	learn: 0.0328525	total: 15.1s	remaining: 1.75s
# 896:	learn: 0.0328079	total: 15.1s	remaining: 1.74s
# 897:	learn: 0.0327754	total: 15.1s	remaining: 1.72s
# 898:	learn: 0.0327450	total: 15.2s	remaining: 1.7s
# 899:	learn: 0.0326774	total: 15.2s	remaining: 1.69s
# 900:	learn: 0.0325708	total: 15.2s	remaining: 1.67s
# 901:	learn: 0.0325281	total: 15.3s	remaining: 1.66s
# 902:	learn: 0.0324387	total: 15.3s	remaining: 1.64s
# 903:	learn: 0.0323902	total: 15.3s	remaining: 1.63s
# 904:	learn: 0.0322970	total: 15.3s	remaining: 1.61s
# 905:	learn: 0.0322519	total: 15.4s	remaining: 1.59s
# 906:	learn: 0.0322259	total: 15.4s	remaining: 1.58s
# 907:	learn: 0.0321786	total: 15.4s	remaining: 1.56s
# 908:	learn: 0.0321224	total: 15.4s	remaining: 1.54s
# 909:	learn: 0.0320506	total: 15.4s	remaining: 1.53s
# 910:	learn: 0.0319895	total: 15.5s	remaining: 1.51s
# 911:	learn: 0.0319521	total: 15.5s	remaining: 1.49s
# 912:	learn: 0.0319047	total: 15.5s	remaining: 1.48s
# 913:	learn: 0.0318140	total: 15.5s	remaining: 1.46s
# 914:	learn: 0.0317223	total: 15.5s	remaining: 1.44s
# 915:	learn: 0.0316506	total: 15.6s	remaining: 1.43s
# 916:	learn: 0.0315745	total: 15.6s	remaining: 1.41s
# 917:	learn: 0.0315129	total: 15.6s	remaining: 1.4s
# 918:	learn: 0.0314800	total: 15.7s	remaining: 1.38s
# 919:	learn: 0.0314112	total: 15.7s	remaining: 1.36s
# 920:	learn: 0.0313655	total: 15.7s	remaining: 1.35s
# 921:	learn: 0.0313181	total: 15.7s	remaining: 1.33s
# 922:	learn: 0.0312463	total: 15.8s	remaining: 1.31s
# 923:	learn: 0.0312036	total: 15.8s	remaining: 1.3s
# 924:	learn: 0.0311449	total: 15.8s	remaining: 1.28s
# 925:	learn: 0.0311097	total: 15.8s	remaining: 1.26s
# 926:	learn: 0.0310468	total: 15.8s	remaining: 1.24s
# 927:	learn: 0.0309902	total: 15.8s	remaining: 1.23s
# 928:	learn: 0.0309409	total: 15.8s	remaining: 1.21s
# 929:	learn: 0.0308960	total: 15.8s	remaining: 1.19s
# 930:	learn: 0.0308652	total: 15.9s	remaining: 1.18s
# 931:	learn: 0.0308087	total: 15.9s	remaining: 1.16s
# 932:	learn: 0.0307569	total: 15.9s	remaining: 1.14s
# 933:	learn: 0.0307027	total: 15.9s	remaining: 1.12s
# 934:	learn: 0.0306551	total: 15.9s	remaining: 1.11s
# 935:	learn: 0.0305937	total: 15.9s	remaining: 1.09s
# 936:	learn: 0.0305443	total: 15.9s	remaining: 1.07s
# 937:	learn: 0.0304758	total: 16s	remaining: 1.05s
# 938:	learn: 0.0304258	total: 16s	remaining: 1.04s
# 939:	learn: 0.0303659	total: 16s	remaining: 1.02s
# 940:	learn: 0.0303062	total: 16s	remaining: 1s
# 941:	learn: 0.0302529	total: 16s	remaining: 986ms
# 942:	learn: 0.0301861	total: 16s	remaining: 969ms
# 943:	learn: 0.0301391	total: 16s	remaining: 952ms
# 944:	learn: 0.0300733	total: 16.1s	remaining: 935ms
# 945:	learn: 0.0300379	total: 16.1s	remaining: 918ms
# 946:	learn: 0.0299929	total: 16.1s	remaining: 901ms
# 947:	learn: 0.0299897	total: 16.1s	remaining: 883ms
# 948:	learn: 0.0299617	total: 16.1s	remaining: 867ms
# 949:	learn: 0.0299032	total: 16.2s	remaining: 850ms
# 950:	learn: 0.0298542	total: 16.2s	remaining: 833ms
# 951:	learn: 0.0298368	total: 16.2s	remaining: 816ms
# 952:	learn: 0.0297674	total: 16.2s	remaining: 799ms
# 953:	learn: 0.0297197	total: 16.2s	remaining: 782ms
# 954:	learn: 0.0296819	total: 16.2s	remaining: 765ms
# 955:	learn: 0.0296053	total: 16.2s	remaining: 747ms
# 956:	learn: 0.0295684	total: 16.3s	remaining: 730ms
# 957:	learn: 0.0295196	total: 16.3s	remaining: 713ms
# 958:	learn: 0.0294575	total: 16.3s	remaining: 696ms
# 959:	learn: 0.0294098	total: 16.3s	remaining: 679ms
# 960:	learn: 0.0293743	total: 16.3s	remaining: 662ms
# 961:	learn: 0.0292993	total: 16.3s	remaining: 645ms
# 962:	learn: 0.0292603	total: 16.3s	remaining: 628ms
# 963:	learn: 0.0292179	total: 16.4s	remaining: 611ms
# 964:	learn: 0.0291898	total: 16.4s	remaining: 593ms
# 965:	learn: 0.0291155	total: 16.4s	remaining: 576ms
# 966:	learn: 0.0290681	total: 16.4s	remaining: 559ms
# 967:	learn: 0.0290289	total: 16.4s	remaining: 542ms
# 968:	learn: 0.0289421	total: 16.4s	remaining: 525ms
# 969:	learn: 0.0288947	total: 16.4s	remaining: 508ms
# 970:	learn: 0.0288501	total: 16.4s	remaining: 491ms
# 971:	learn: 0.0288123	total: 16.5s	remaining: 474ms
# 972:	learn: 0.0287536	total: 16.5s	remaining: 457ms
# 973:	learn: 0.0287010	total: 16.5s	remaining: 440ms
# 974:	learn: 0.0286467	total: 16.5s	remaining: 423ms
# 975:	learn: 0.0285704	total: 16.5s	remaining: 406ms
# 976:	learn: 0.0285398	total: 16.5s	remaining: 389ms
# 977:	learn: 0.0284967	total: 16.5s	remaining: 372ms
# 978:	learn: 0.0284508	total: 16.5s	remaining: 355ms
# 979:	learn: 0.0284267	total: 16.6s	remaining: 338ms
# 980:	learn: 0.0283950	total: 16.6s	remaining: 321ms
# 981:	learn: 0.0283489	total: 16.6s	remaining: 304ms
# 982:	learn: 0.0282831	total: 16.6s	remaining: 287ms
# 983:	learn: 0.0282366	total: 16.6s	remaining: 270ms
# 984:	learn: 0.0282200	total: 16.6s	remaining: 253ms
# 985:	learn: 0.0281673	total: 16.6s	remaining: 236ms
# 986:	learn: 0.0280788	total: 16.7s	remaining: 219ms
# 987:	learn: 0.0280134	total: 16.7s	remaining: 203ms
# 988:	learn: 0.0279809	total: 16.7s	remaining: 186ms
# 989:	learn: 0.0279553	total: 16.8s	remaining: 169ms
# 990:	learn: 0.0279017	total: 16.8s	remaining: 152ms
# 991:	learn: 0.0278351	total: 16.8s	remaining: 135ms
# 992:	learn: 0.0277779	total: 16.8s	remaining: 119ms
# 993:	learn: 0.0277296	total: 16.9s	remaining: 102ms
# 994:	learn: 0.0276877	total: 17s	remaining: 85.4ms
# 995:	learn: 0.0276325	total: 17s	remaining: 68.4ms
# 996:	learn: 0.0276067	total: 17.1s	remaining: 51.4ms
# 997:	learn: 0.0275891	total: 17.1s	remaining: 34.3ms
# 998:	learn: 0.0275257	total: 17.1s	remaining: 17.1ms
# 999:	learn: 0.0274891	total: 17.1s	remaining: 0us

# %%
#model_a = tfdf.keras.GradientBoostedTreesModel(task=tfdf.keras.Task.REGRESSION)
#model_b = tfdf.keras.GradientBoostedTreesModel(task=tfdf.keras.Task.REGRESSION)
#model_c = tfdf.keras.GradientBoostedTreesModel(task=tfdf.keras.Task.REGRESSION)

# Convert the dataset into a TensorFlow dataset.
#train_ds_a = tfdf.keras.pd_dataframe_to_tf_dataset(A[0], label='pv_measurement', task=tfdf.keras.Task.REGRESSION)
#train_ds_b = tfdf.keras.pd_dataframe_to_tf_dataset(B[0], label='pv_measurement', task=tfdf.keras.Task.REGRESSION)
#train_ds_c = tfdf.keras.pd_dataframe_to_tf_dataset(C[0], label='pv_measurement', task=tfdf.keras.Task.REGRESSION)

# Train a Random Forest model.
#model_a.fit(train_ds_a)
#model_b.fit(train_ds_b)
#model_c.fit(train_ds_c)

# %%
#Plot model to file
#tfdf.model_plotter.DisplayOptions(
#    margin=10,
#    node_x_size=160,
#    node_y_size=28,
#    node_x_offset=180,
#    node_y_offset=33,
#    font_size=10,
#    edge_rounding=20,
#    node_padding=2,
#   show_plot_bounding_box=False
#)

#with open("plot.html", "w") as f:
#    f.write(tfdf.model_plotter.plot_model(model_a))

# %%
validation_ds_a = tfdf.keras.pd_dataframe_to_tf_dataset(A[1], label='pv_measurement', task=tfdf.keras.Task.REGRESSION)
validation_ds_b = tfdf.keras.pd_dataframe_to_tf_dataset(B[1], label='pv_measurement', task=tfdf.keras.Task.REGRESSION)
validation_ds_c = tfdf.keras.pd_dataframe_to_tf_dataset(C[1], label='pv_measurement', task=tfdf.keras.Task.REGRESSION)

# Summary of the model structure.
#model_a.summary()
#model_b.summary()
#model_c.summary()

validation_a = model_a.predict(validation_ds_a)
validation_b = model_b.predict(validation_ds_b)
validation_c = model_c.predict(validation_ds_c)

validation_a[validation_a < 0] = 0
validation_b[validation_b < 0] = 0
validation_c[validation_c < 0] = 0

actual_values_a = A[1]['pv_measurement']
actual_values_b = B[1]['pv_measurement']
actual_values_c = C[1]['pv_measurement']

print(np.mean(tf.keras.metrics.mean_absolute_error(
    actual_values_a, validation_a
)))
print(np.mean(tf.keras.metrics.mean_absolute_error(
    actual_values_b, validation_b
)))
print(np.mean(tf.keras.metrics.mean_absolute_error(
    actual_values_c, validation_c
)))
# Out:
# 5/5 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 36ms/step
# 3/3 [==============================] - 0s 44ms/step
# 596.73804
# 78.70909
# 76.153275

# %%
# Plotting Prediction vs. Actual
plt.plot(actual_values_a, label='Actual', color='red')
plt.plot(validation_a, label='Predicted', color='blue')
plt.xlabel('Time')
plt.ylabel('pv_measurement')
plt.title('Prediction vs. Actual')
plt.legend()
plt.show()

# Plotting Prediction vs. Actual
plt.plot(actual_values_b, label='Actual', color='red')
plt.plot(validation_b, label='Predicted', color='blue')
plt.xlabel('Time')
plt.ylabel('pv_measurement')
plt.title('Prediction vs. Actual')
plt.legend()
plt.show()

# Plotting Prediction vs. Actual
plt.plot(actual_values_c, label='Actual', color='red')
plt.plot(validation_c, label='Predicted', color='blue')
plt.xlabel('Time')
plt.ylabel('pv_measurement')
plt.title('Prediction vs. Actual')
plt.legend()
plt.show()

# %%
#meta_X = np.column_stack((validation_a., validation_b, validation_c))
#meta_model = tfdf.keras.RandomForestModel(task=tfdf.keras.Task.REGRESSION)
#meta_model.fit(meta_X, y)
#combined_predictions = meta_model.predict(meta_X)

# %%
test_ds_a = tfdf.keras.pd_dataframe_to_tf_dataset(A[2], task=tfdf.keras.Task.REGRESSION)
test_ds_b = tfdf.keras.pd_dataframe_to_tf_dataset(B[2], task=tfdf.keras.Task.REGRESSION)
test_ds_c = tfdf.keras.pd_dataframe_to_tf_dataset(C[2], task=tfdf.keras.Task.REGRESSION)

prediction_a = model_a.predict(test_ds_a)
prediction_b = model_b.predict(test_ds_b)
prediction_c = model_c.predict(test_ds_c)

prediction_a[prediction_a < 0] = 0
prediction_b[prediction_b < 0] = 0
prediction_c[prediction_c < 0] = 0

submit = np.concatenate((np.concatenate((prediction_a, prediction_b)),prediction_c))
# Out:
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 130ms/step

# %%
test = pd.read_csv('test.csv')

test
# Out:
#         id                 time  prediction location
# 0        0  2023-05-01 00:00:00           0        A
# 1        1  2023-05-01 01:00:00           0        A
# 2        2  2023-05-01 02:00:00           0        A
# 3        3  2023-05-01 03:00:00           0        A
# 4        4  2023-05-01 04:00:00           0        A
# ...    ...                  ...         ...      ...
# 2155  2155  2023-07-03 19:00:00           0        C
# 2156  2156  2023-07-03 20:00:00           0        C
# 2157  2157  2023-07-03 21:00:00           0        C
# 2158  2158  2023-07-03 22:00:00           0        C
# 2159  2159  2023-07-03 23:00:00           0        C
#
# [2160 rows x 4 columns]

# %%
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission
# Out:
#         id  prediction
# 0        0           0
# 1        1           0
# 2        2           0
# 3        3           0
# 4        4           0
# ...    ...         ...
# 2155  2155           0
# 2156  2156           0
# 2157  2157           0
# 2158  2158           0
# 2159  2159           0
#
# [2160 rows x 2 columns]

# %%
# Example, let the predictions be random values
test['prediction'] = submit
sample_submission = sample_submission[['id']].merge(test[['id', 'prediction']], on='id', how='left')
sample_submission.to_csv("gradient_boosted_submissions/gradient_boosted_1.csv", index=False)

# %%
#Plot full sequence

pv_measurement_1 = A[0]['pv_measurement']

# Convert arr2 and arr3 to pandas Series
pv_measurement_2 = pd.Series(validation_a.flatten(), name='pv_measurement')
pv_measurement_3 = pd.Series(prediction_a.flatten(), name='pv_measurement')

# Concatenate the three Series
pv_measurement_combined = pd.concat([pv_measurement_1, pv_measurement_2, pv_measurement_3])

# Generate an index for the x-axis
index = range(len(pv_measurement_combined))

# Plot the data
plt.plot(index, pv_measurement_combined, label='pv_measurement')

# Add labels and title if needed
plt.xlabel('Index')
plt.ylabel('pv_measurement')
plt.title('pv_measurement over Time')

# Show the plot
plt.legend()
plt.show()

# %%
#Plot full sequence

pv_measurement_1 = B[0]['pv_measurement']

# Convert arr2 and arr3 to pandas Series
pv_measurement_2 = pd.Series(validation_b.flatten(), name='pv_measurement')
pv_measurement_3 = pd.Series(prediction_b.flatten(), name='pv_measurement')

# Concatenate the three Series
pv_measurement_combined = pd.concat([pv_measurement_1, pv_measurement_2, pv_measurement_3])

# Generate an index for the x-axis
index = range(len(pv_measurement_combined))

# Plot the data
plt.plot(index, pv_measurement_combined, label='pv_measurement')

# Add labels and title if needed
plt.xlabel('Index')
plt.ylabel('pv_measurement')
plt.title('pv_measurement over Time')

# Show the plot
plt.legend()
plt.show()

# %%
#Plot full sequence

pv_measurement_1 = C[0]['pv_measurement']

# Convert arr2 and arr3 to pandas Series
pv_measurement_2 = pd.Series(validation_c.flatten(), name='pv_measurement')
pv_measurement_3 = pd.Series(prediction_c.flatten(), name='pv_measurement')

# Concatenate the three Series
pv_measurement_combined = pd.concat([pv_measurement_1, pv_measurement_2, pv_measurement_3])

# Generate an index for the x-axis
index = range(len(pv_measurement_combined))

# Plot the data
plt.plot(index, pv_measurement_combined, label='pv_measurement')

# Add labels and title if needed
plt.xlabel('Index')
plt.ylabel('pv_measurement')
plt.title('pv_measurement over Time')

# Show the plot
plt.legend()
plt.show()
